# %% [markdown]
# # Imports

# %%
import csv
import os
import re

import spacy

# %% [markdown]
# On importe les librairies :
# * os est seulement ici au cas où on voudrait se retrouver dans l'arborescence des dossiers.
# * spacy pour les tests de NLP.
# * re pour aider au preprocessing.

# %% [markdown]
# # Instanciation du modèle de langue pour spaCy

# %% [markdown]
# On utilise le modèle [fr_core_news_lg](https://spacy.io/models/fr#fr_core_news_lg).

# %%
nlp = spacy.load("fr_core_news_lg")

# %% [markdown]
# On affiche les metadonnées du modèle de langue.

# %%
nlp.meta
# Out:
# {'lang': 'fr',
#  'name': 'core_news_lg',
#  'version': '3.0.0',
#  'spacy_version': '>=3.0.0,<3.1.0',
#  'description': 'French pipeline optimized for CPU. Components: tok2vec, morphologizer, parser, senter, ner, attribute_ruler, lemmatizer.',
#  'author': 'Explosion',
#  'email': 'contact@explosion.ai',
#  'url': 'https://explosion.ai',
#  'license': 'LGPL-LR',
#  'spacy_git_version': 'e7db07a0b',
#  'vectors': {'width': 300,
#   'vectors': 500000,
#   'keys': 500000,
#   'name': 'fr_vectors'},
#  'labels': {'tok2vec': [],
#   'morphologizer': ['POS=PROPN',
#    'Gender=Fem|Number=Sing|POS=DET|PronType=Dem',
#    'Gender=Fem|Number=Sing|POS=NOUN',
#    'Number=Plur|POS=PRON|Person=1',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'POS=SCONJ',
#    'POS=ADP',
#    'Definite=Def|Gender=Masc|Number=Sing|POS=DET|PronType=Art',
#    'NumType=Ord|POS=ADJ',
#    'Gender=Masc|Number=Sing|POS=NOUN',
#    'POS=PUNCT',
#    'Gender=Masc|Number=Sing|POS=PROPN',
#    'Number=Plur|POS=ADJ',
#    'Gender=Masc|Number=Plur|POS=NOUN',
#    'Definite=Ind|Gender=Fem|Number=Sing|POS=DET|PronType=Art',
#    'Number=Sing|POS=ADJ',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=3|Tense=Imp|VerbForm=Fin',
#    'POS=ADV',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Definite=Def|Gender=Fem|Number=Sing|POS=DET|PronType=Art',
#    'Gender=Fem|Number=Sing|POS=PROPN',
#    'Definite=Def|Number=Sing|POS=DET|PronType=Art',
#    'NumType=Card|POS=NUM',
#    'Definite=Def|Number=Plur|POS=DET|PronType=Art',
#    'Gender=Masc|Number=Plur|POS=ADJ',
#    'POS=CCONJ',
#    'Gender=Fem|Number=Plur|POS=NOUN',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|POS=VERB|Tense=Past|VerbForm=Part',
#    'Gender=Fem|Number=Plur|POS=ADJ',
#    'POS=ADJ',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=3|Tense=Past|VerbForm=Fin',
#    'POS=PRON|PronType=Rel',
#    'Number=Sing|POS=DET|Poss=Yes',
#    'Definite=Def|Gender=Masc|Number=Sing|POS=ADP|PronType=Art',
#    'Definite=Def|Number=Plur|POS=ADP|PronType=Art',
#    'Definite=Ind|Number=Plur|POS=DET|PronType=Art',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Masc|Number=Plur|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'POS=VERB|VerbForm=Inf',
#    'Gender=Fem|Number=Sing|POS=ADJ',
#    'Gender=Masc|Number=Sing|POS=PRON|Person=3',
#    'Number=Plur|POS=DET',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|POS=ADJ',
#    'Gender=Masc|Number=Sing|POS=DET|PronType=Dem',
#    'POS=ADV|PronType=Int',
#    'POS=VERB|Tense=Pres|VerbForm=Part',
#    'Gender=Fem|Number=Sing|POS=VERB|Tense=Past|VerbForm=Part',
#    'Definite=Ind|Gender=Masc|Number=Sing|POS=DET|PronType=Art',
#    'Gender=Masc|POS=ADJ',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=3|Tense=Fut|VerbForm=Fin',
#    'Number=Plur|POS=DET|Poss=Yes',
#    'POS=AUX|VerbForm=Inf',
#    'Gender=Masc|Number=Sing|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Gender=Masc|POS=VERB|Tense=Past|VerbForm=Part',
#    'POS=ADV|Polarity=Neg',
#    'Definite=Ind|Number=Sing|POS=DET|PronType=Art',
#    'Gender=Fem|Number=Sing|POS=PRON|Person=3',
#    'POS=PRON|Person=3|Reflex=Yes',
#    'Gender=Masc|POS=NOUN',
#    'POS=AUX|Tense=Past|VerbForm=Part',
#    'POS=PRON|Person=3',
#    'Number=Plur|POS=NOUN',
#    'NumType=Ord|Number=Sing|POS=ADJ',
#    'POS=VERB|Tense=Past|VerbForm=Part',
#    'POS=AUX|Tense=Pres|VerbForm=Part',
#    'Gender=Masc|Number=Plur|POS=VERB|Tense=Past|VerbForm=Part',
#    'Number=Sing|POS=PRON|Person=3',
#    'Number=Sing|POS=NOUN',
#    'Gender=Masc|Number=Plur|POS=PRON|Person=3',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Fem|NumType=Ord|Number=Sing|POS=ADJ',
#    'Number=Plur|POS=PROPN',
#    'Number=Sing|POS=PROPN',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=3|Tense=Imp|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Plur|POS=PRON|PronType=Dem',
#    'Gender=Masc|Number=Sing|POS=DET',
#    'Gender=Fem|Number=Sing|POS=DET|Poss=Yes',
#    'Gender=Masc|POS=PRON',
#    'POS=NOUN',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=3|Tense=Fut|VerbForm=Fin',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=3|Tense=Fut|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Number=Plur|POS=PRON',
#    'Gender=Masc|NumType=Ord|Number=Plur|POS=ADJ',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=3|Tense=Fut|VerbForm=Fin',
#    'Gender=Fem|Number=Plur|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Number=Sing|POS=PRON',
#    'Number=Sing|POS=PRON|PronType=Dem',
#    'Mood=Ind|POS=VERB|VerbForm=Fin',
#    'Number=Plur|POS=DET|PronType=Dem',
#    'Gender=Masc|Number=Sing|POS=PRON|Person=3|PronType=Prs',
#    'Gender=Masc|Number=Plur|POS=PRON|Person=3|PronType=Prs',
#    'Gender=Masc|Number=Sing|POS=PRON',
#    'Gender=Masc|Number=Sing|POS=PRON|Person=3|PronType=Dem',
#    'Number=Sing|POS=PRON|Person=2|PronType=Prs',
#    'Gender=Masc|Number=Sing|POS=PRON|PronType=Rel',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=3|Tense=Imp|VerbForm=Fin',
#    'Mood=Sub|Number=Sing|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|NumType=Ord|Number=Sing|POS=ADJ',
#    'POS=PRON',
#    'POS=NUM',
#    'Gender=Fem|POS=NOUN',
#    'Gender=Fem|Number=Plur|POS=PRON',
#    'Number=Plur|POS=PRON|Person=3',
#    'Number=Sing|POS=VERB|Tense=Past|VerbForm=Part',
#    'Number=Sing|POS=PRON|Person=1',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Sub|Number=Sing|POS=VERB|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|POS=PRON',
#    'Gender=Fem|Number=Sing|POS=PRON|Person=3|PronType=Prs',
#    'Mood=Sub|Number=Sing|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'POS=INTJ',
#    'Number=Plur|POS=PRON|Person=2',
#    'NumType=Card|POS=PRON',
#    'Definite=Ind|Gender=Fem|Number=Plur|POS=DET|PronType=Art',
#    'Gender=Fem|Number=Plur|POS=VERB|Tense=Past|VerbForm=Part',
#    'NumType=Card|POS=NOUN',
#    'POS=PRON|PronType=Int',
#    'Gender=Fem|Number=Plur|POS=PRON|Person=3',
#    'Gender=Fem|Number=Sing|POS=DET',
#    'Mood=Cnd|Number=Sing|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Fem|Number=Plur|POS=DET',
#    'Mood=Sub|Number=Plur|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'Definite=Ind|Gender=Masc|Number=Plur|POS=DET|PronType=Art',
#    'Mood=Cnd|Number=Sing|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|POS=PRON|PronType=Dem',
#    'Gender=Masc|Number=Plur|POS=PROPN',
#    'Mood=Cnd|Number=Plur|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|POS=PRON|PronType=Dem',
#    'Number=Sing|POS=DET',
#    'Gender=Masc|NumType=Card|Number=Plur|POS=NOUN',
#    'Gender=Fem|Number=Plur|POS=PRON|PronType=Dem',
#    'Mood=Ind|POS=VERB|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Fem|POS=PRON',
#    'Gender=Masc|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Gender=Fem|Number=Sing|POS=PRON|PronType=Rel',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=1|Tense=Imp|VerbForm=Fin',
#    'Mood=Cnd|Number=Plur|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|POS=AUX|Tense=Past|VerbForm=Part',
#    'POS=X',
#    'POS=SYM',
#    'Mood=Imp|Number=Plur|POS=VERB|Person=2|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=2|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|POS=DET|PronType=Int',
#    'Gender=Fem|Number=Plur|POS=DET|PronType=Int',
#    'POS=DET',
#    'Gender=Masc|Number=Plur|POS=PRON',
#    'POS=PART',
#    'Mood=Sub|Number=Plur|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|POS=VERB|Person=3|VerbForm=Fin',
#    'Number=Sing|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Mood=Cnd|Number=Plur|POS=VERB|Person=2|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=2|Tense=Pres|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|POS=DET|PronType=Int',
#    'Gender=Masc|Number=Plur|POS=DET',
#    'Gender=Fem|Number=Plur|POS=PRON|PronType=Rel',
#    'Number=Plur|POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Gender=Masc|Number=Plur|POS=PRON|PronType=Rel',
#    'POS=VERB|Tense=Past|VerbForm=Part|Voice=Pass',
#    'Gender=Fem|NumType=Ord|Number=Plur|POS=ADJ',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=2|Tense=Fut|VerbForm=Fin',
#    'Mood=Imp|POS=VERB|Tense=Pres|VerbForm=Fin',
#    'Number=Plur|POS=PRON|Person=2|Reflex=Yes',
#    'Mood=Cnd|Number=Sing|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Number=Plur|POS=PRON|Person=1|Reflex=Yes',
#    'Gender=Masc|NumType=Card|Number=Sing|POS=NOUN',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=1|Tense=Fut|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=1|Tense=Fut|VerbForm=Fin',
#    'Number=Sing|POS=PRON|Person=1|Reflex=Yes',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=1|Tense=Imp|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=AUX|Person=1|Tense=Imp|VerbForm=Fin',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=1|Tense=Imp|VerbForm=Fin',
#    'Mood=Sub|Number=Sing|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|POS=PROPN',
#    'Mood=Cnd|Number=Plur|POS=AUX|Person=3|Tense=Pres|VerbForm=Fin',
#    'Number=Plur|POS=PRON|Person=1|PronType=Prs',
#    'Mood=Sub|Number=Sing|POS=AUX|Person=1|Tense=Pres|VerbForm=Fin',
#    'Number=Plur|POS=PRON|Person=2|PronType=Prs',
#    'Mood=Ind|Number=Sing|POS=VERB|Person=1|Tense=Fut|VerbForm=Fin',
#    'Gender=Fem|Number=Plur|POS=PRON|Person=3|PronType=Prs',
#    'Number=Sing|POS=PRON|Person=1|PronType=Prs',
#    'Mood=Cnd|Number=Sing|POS=AUX|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Sub|Number=Plur|POS=AUX|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Imp|Number=Plur|POS=VERB|Person=1|Tense=Pres|VerbForm=Fin',
#    'Mood=Sub|Number=Plur|POS=AUX|Person=2|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Plur|POS=VERB|Person=2|Tense=Imp|VerbForm=Fin',
#    'Gender=Fem|POS=ADV',
#    'Mood=Ind|Number=Sing|POS=AUX|Person=2|Tense=Imp|VerbForm=Fin',
#    'Number=Plur|POS=VERB|Tense=Past|VerbForm=Part',
#    'Gender=Fem|Number=Plur|POS=PROPN',
#    'Gender=Masc|NumType=Card|POS=NUM'],
#   'parser': ['ROOT',
#    'acl',
#    'acl:relcl',
#    'advcl',
#    'advmod',
#    'amod',
#    'appos',
#    'aux:pass',
#    'aux:tense',
#    'case',
#    'cc',
#    'ccomp',
#    'conj',
#    'cop',
#    'dep',
#    'det',
#    'expl:comp',
#    'expl:pass',
#    'expl:subj',
#    'fixed',
#    'flat:foreign',
#    'flat:name',
#    'iobj',
#    'mark',
#    'nmod',
#    'nsubj',
#    'nsubj:pass',
#    'nummod',
#    'obj',
#    'obl:agent',
#    'obl:arg',
#    'obl:mod',
#    'parataxis',
#    'punct',
#    'vocative',
#    'xcomp'],
#   'senter': ['I', 'S'],
#   'ner': ['LOC', 'MISC', 'ORG', 'PER'],
#   'attribute_ruler': [],
#   'lemmatizer': []},
#  'pipeline': ['tok2vec',
#   'morphologizer',
#   'parser',
#   'ner',
#   'attribute_ruler',
#   'lemmatizer'],
#  'components': ['tok2vec',
#   'morphologizer',
#   'parser',
#   'senter',
#   'ner',
#   'attribute_ruler',
#   'lemmatizer'],
#  'disabled': ['senter'],
#  'performance': {'token_acc': 0.9989751998,
#   'tag_acc': 0.9463706146,
#   'pos_acc': 0.9751172016,
#   'morph_acc': 0.9702123274000001,
#   'lemma_acc': 0.9078954127000001,
#   'dep_uas': 0.8985306028000001,
#   'dep_las': 0.8625954198,
#   'sents_p': 0.8654292343000001,
#   'sents_r': 0.9089263224,
#   'sents_f': 0.8849347568,
#   'speed': 4797.3359485882,
#   'morph_per_feat': {'Definite': {'p': 0.9933969186,
#     'r': 0.9876002918000001,
#     'f': 0.9904901244000001},
#    'Number': {'p': 0.9958886189, 'r': 0.9875833951, 'f': 0.9917186191},
#    'PronType': {'p': 0.998065764, 'r': 0.9897698210000001, 'f': 0.9939004815},
#    'Gender': {'p': 0.98855359, 'r': 0.9819121447, 'f': 0.9852216749},
#    'Mood': {'p': 0.9782608696, 'r': 0.9591474245, 'f': 0.9686098655000001},
#    'Person': {'p': 0.9936224490000001, 'r': 0.9786432161, 'f': 0.9860759494},
#    'Tense': {'p': 0.9772727273, 'r': 0.9662921348, 'f': 0.9717514124000001},
#    'VerbForm': {'p': 0.9865996650000001,
#     'r': 0.9751655629,
#     'f': 0.9808492923000001},
#    'NumType': {'p': 1.0, 'r': 0.9551724138000001, 'f': 0.9770723104000001},
#    'Reflex': {'p': 1.0, 'r': 1.0, 'f': 1.0},
#    'Voice': {'p': 0.9310344828, 'r': 0.9642857143, 'f': 0.9473684211000001},
#    'Poss': {'p': 1.0, 'r': 1.0, 'f': 1.0},
#    'Polarity': {'p': 1.0, 'r': 0.9882352941, 'f': 0.9940828402}},
#   'dep_las_per_type': {'det': {'p': 0.9845779221000001,
#     'r': 0.9790153349,
#     'f': 0.9817887495000001},
#    'nsubj': {'p': 0.8875305623, 'r': 0.8746987952, 'f': 0.8810679612000001},
#    'aux:tense': {'p': 0.9147286822,
#     'r': 0.9440000000000001,
#     'f': 0.9291338583000001},
#    'root': {'p': 0.8837209302000001,
#     'r': 0.9223300971,
#     'f': 0.9026128266000001},
#    'obj': {'p': 0.8483965015, 'r': 0.8635014837, 'f': 0.8558823529},
#    'cc': {'p': 0.8847926267, 'r': 0.8847926267, 'f': 0.8847926267},
#    'case': {'p': 0.9716024341,
#     'r': 0.9788828338000001,
#     'f': 0.9752290465000001},
#    'obl:mod': {'p': 0.6960784314, 'r': 0.6339285714, 'f': 0.6635514019000001},
#    'nmod': {'p': 0.8173996176, 'r': 0.8532934132000001, 'f': 0.8349609375},
#    'conj': {'p': 0.5175097276, 'r': 0.5236220472, 'f': 0.5205479452},
#    'nummod': {'p': 0.9182389937000001, 'r': 0.869047619, 'f': 0.8929663609},
#    'amod': {'p': 0.9288321168, 'r': 0.9288321168, 'f': 0.9288321168},
#    'acl': {'p': 0.6836158192, 'r': 0.6994219653, 'f': 0.6914285714},
#    'mark': {'p': 0.9049773756, 'r': 0.8810572687, 'f': 0.8928571429000001},
#    'xcomp': {'p': 0.8571428571, 'r': 0.7947019868, 'f': 0.8247422680000001},
#    'flat:name': {'p': 0.9126213592,
#     'r': 0.8952380952000001,
#     'f': 0.9038461538},
#    'cop': {'p': 0.8913043478, 'r': 0.9111111111, 'f': 0.9010989011},
#    'advmod': {'p': 0.8647798742, 'r': 0.8620689655, 'f': 0.8634222920000001},
#    'obl:arg': {'p': 0.6990740741, 'r': 0.6863636364, 'f': 0.6926605505},
#    'appos': {'p': 0.5, 'r': 0.5060240964, 'f': 0.502994012},
#    'nsubj:pass': {'p': 0.9358974359000001,
#     'r': 0.8588235294000001,
#     'f': 0.8957055215},
#    'aux:pass': {'p': 0.9724770642, 'r': 0.9464285714, 'f': 0.9592760181000001},
#    'acl:relcl': {'p': 0.6162790698, 'r': 0.6162790698, 'f': 0.6162790698},
#    'advcl': {'p': 0.5714285714, 'r': 0.5128205128000001, 'f': 0.5405405405},
#    'fixed': {'p': 0.8915662651, 'r': 0.7326732673, 'f': 0.8043478261},
#    'dep': {'p': 0.2638888889, 'r': 0.6129032258, 'f': 0.36893203880000003},
#    'expl:subj': {'p': 0.7878787879, 'r': 0.8125, 'f': 0.8},
#    'expl:comp': {'p': 0.6216216216,
#     'r': 0.7666666667,
#     'f': 0.6865671642000001},
#    'expl:pass': {'p': 0.2857142857, 'r': 0.2857142857, 'f': 0.2857142857},
#    'ccomp': {'p': 0.8085106383, 'r': 0.7450980392000001, 'f': 0.7755102041},
#    'parataxis': {'p': 0.5789473684, 'r': 0.3928571429, 'f': 0.4680851064},
#    'iobj': {'p': 0.7222222222, 'r': 0.52, 'f': 0.6046511628},
#    'obl:agent': {'p': 0.9268292683,
#     'r': 0.9047619048000001,
#     'f': 0.9156626506000001},
#    'nsubj:caus': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'aux:caus': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'obj:agent': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'goeswith': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'vocative': {'p': 1.0, 'r': 0.625, 'f': 0.7692307692},
#    'dislocated': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'flat:foreign': {'p': 1.0, 'r': 0.2857142857, 'f': 0.4444444444},
#    'orphan': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'advcl:cleft': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#    'csubj': {'p': 0.0, 'r': 0.0, 'f': 0.0}},
#   'ents_p': 0.8497016610000001,
#   'ents_r': 0.8436811977,
#   'ents_f': 0.8466807271000001,
#   'ents_per_type': {'PER': {'p': 0.9129822585,
#     'r': 0.9291394999,
#     'f': 0.9209900217},
#    'LOC': {'p': 0.8468624778, 'r': 0.8575253075, 'f': 0.8521605387000001},
#    'ORG': {'p': 0.8055722590000001, 'r': 0.7669847328, 'f': 0.785805064},
#    'MISC': {'p': 0.7514497423000001, 'r': 0.6801282986, 'f': 0.7140123976}}},
#  'sources': [{'name': 'UD French Sequoia v2.5',
#    'url': 'https://github.com/UniversalDependencies/UD_French-Sequoia',
#    'license': 'LGPL-LR',
#    'author': 'Candito, Marie; Seddah, Djamé; Perrier, Guy; Guillaume, Bruno'},
#   {'name': 'WikiNER',
#    'url': 'https://figshare.com/articles/Learning_multilingual_named_entity_recognition_from_Wikipedia/5462500',
#    'license': 'CC BY 4.0'}],
#  'requirements': []}

# %% [markdown]
# Quatre entités nommées sont reconnues par ce modèle :
# * LOC
# * MISC
# * ORG
# * PER
#
# Le premier objectif consistera à essayer de détecter en priorité les localisations ('LOC'), les organisations ('ORG') et les personnes ('PER').

# %% [markdown]
# # Analyse d'un échantillon propre (transcription manuelle)

# %% [markdown]
# On ouvre un fichier échantillon issu d'un document du projet LECTAUREP transcrit manuellement, et dont la segmentation a été modifiée : seule la colonne centrale a été gardée.

# %%
with open("../../corpus_test/lectaurep/spaCy_bac_a_sable/sample_doc28_central_column.txt", 'r', encoding='utf-8') as file:
    sample = file.read()

# %%
sample
# Out:
# 'An 1901 , mois de Février\nDupuis, (par Pierre) à Paris, rue Turgot 4, à Catherine Bizial, sa femme\n- d° - (par Mme) s. n. à son mari\nMurel (par Paul Louis Georges) dt à Paris, Bd Rochechouart 68, et Marie Joséphine\nLemaire, dt à Paris, même adresse (Séparation de biens)\nDubosc (ct titre de 380+ de rente 3% au nom  de : Debuisson, Justine Adèle,\nVve de Jules) et autres, à Paris, rue de l’Arcade 20\nRouy (par Edmond Narcisse), dt à Paris, rue Cavalotti 15, et autres, pr toucher &amp; recevoir\nChabrol (par Marie Louise Vatonne, Ve de Marie Eusèbe Maxime) dt à Billancourt, route de \nVersailles, 128, à Eugène Vatrin et Marceline Freling, dt à Billancourt, rue Nationale 31, de 21 303,88\nGauthier (par Marie Alexandrine) à Paris, rue St Ferdinand 2, à ses père et mère\nCusson (par Georges Ernest Léon) dt à Paris, rue Lamarck 144, à son père\nLecrosnier (ct livret de caisse d’Epargne de Paris, de 157,19 au nom de Pierre\nAuguste) décédé en son domicile à Paris, rue Descartes 21, le 16 8bre 1900\nLettéron (ct les prénoms de Louis Emile) décédé en son dom. à Villeneuve-St Georges, le 15 7bre 1897\nDupont (par Léonie Albertine Octavie) rue St-Lazare 82, à Honoré Bouscarat et sa\nfemme, à Montelaux (Aveyron) et à Achille Dareau, rue Guyot 17 de boutique aud. lieu\nde Lecanta y Mendieta (ct Joaquina Dolores Conception de Orbeta y\nAlguirre Ve Manuel), décédée à Bilbat, 23 calle de Btodebarriéta le 25 Mai 1900\nThéoule (par Alfred Sylvain Georges) dt à Paris, rue Bracq, 4, à sa mère\nde Neufville (par Jacob Guillaume) dt à Paris, rue Halévy 6, de valeurs dotales appt à Mme de Boissieux\nde Morangiès (de Marie Gertrude Oboril, épouse de Clodomir Albert) dt à\nParis, rue du Printemps, 22\n- d° - (dud. état)\nSté Block frères et Cie (par la Sté) siège à Toul, à Gabriel Henri Coujat,\nrue du Printemps 7, de 7.875+\nHenry (par Augustine Victoire Lecharpentier, épouse de Jean-Baptiste) à Paris,\nrue d’Athènes, 24, au mariage de sa fille\nMoreau Simond (par Gustave Arthur Félix) et Marie Françoise Pellerin ;\nEpx à Paris rue des Batignolles 76, pr vendre immeuble\nHarant (par Marthe Caroline Duval, rue Pigalle 11b, Ve de Alexandre Victor Armand) \nà Joseph Eugène Bogel et Marie Adelphine Julien, à Asnières, rue de Châteaudun 22, pr 10000+ px de vente \nPrat (ct livret de caisse des retraites pour la vieillesse , 150 + au nom de Jean\nJoseph) décédé en son dom. à Paris, rue de l’Annonciation 28, le 23 8bre 1900\nBoudon (de Pauline Antoinette Meyer, veen 1eres noces de Alexandre Chatel et en 2es\nnoces de François) décédé en son dom. à Paris, rue de Courcelles 192, le 21 février 1901\nde Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à Juan Mariano\nCte de Guagui, Mis de Villafuerte, même adresse, pr acq. de la Sté des Coteaux de Longchamps\nSté des locomotives sans foyer (ct la) par Léon Francq, à Paris \n48 avenue Victor Hugo\nLebedel (de Albéric Jean-Baptiste) à Paris, avenue Victoria 17, et Lucie Augustine \nHenry, à Paris rue d’Athènes 24 (communauté réduites aux acquêts)\nde Goyenèche (par Juan Mariano de Goyenèche y Gannio comte de Guagui,\ndt à Paris avenue de Friedland 15, et autres\nde Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à la Sté Fse des Coteaux du\nBois de Boulogne et de Longchamps, siège à Paris rue de l’Isly 9,  de 3 parcelles de terrain moyt 189585+\nGuille Stevens Le Marchant (ct titre de 396+ de rente 3% au nom de) Henri, dt à\nGrumbanck Croconhill Plymouth Conté de Devon (Angleterre) décédé le 9 mai 1900 à Sadysmith\nKnaier (par Françoise Rouchard, épouse de Alphonse), rue Laferrière 17, pr retirer \ntoutes sommes de la Caisse d’Epargne postale\nDutrey (par Marguerite Elvire Herneis, épouse de Jean Victor) dt à Paris, rue \nLegendre 176, pr recueillir SSon\nManot (par Engrace Millacet, épouse de Pierre) dt à Paris, rue de Grenelle,\n55, à M. Pillard, clerc\nFournié (après décès de Marie Muller, Ve de Marcelin) décédée en son domicile à\nParis, rue Beuret 20, le 11 février 1901\nTeil (par le  ...

# %% [markdown]
# On le normalise :
#
# * Suppression des \n
# * Ajout d'un espace avant les majuscules, pour essayer de faciliter l'analyse et la segmentation des mots. Cela ne marchera pas partout, mais permettra de mettre en évidence les noms propres dans un premier temps.

# %%
# On utilise une regex pour ajouter un espace avant les majuscules
sample_norm = re.sub(r"(\w)([A-Z])", r"\1 \2", sample)

# %%
sample_norm
# Out:
# 'An 1901 , mois de Février\nDupuis, (par Pierre) à Paris, rue Turgot 4, à Catherine Bizial, sa femme\n- d° - (par Mme) s. n. à son mari\nMurel (par Paul Louis Georges) dt à Paris, Bd Rochechouart 68, et Marie Joséphine\nLemaire, dt à Paris, même adresse (Séparation de biens)\nDubosc (ct titre de 380+ de rente 3% au nom  de : Debuisson, Justine Adèle,\nVve de Jules) et autres, à Paris, rue de l’Arcade 20\nRouy (par Edmond Narcisse), dt à Paris, rue Cavalotti 15, et autres, pr toucher &amp; recevoir\nChabrol (par Marie Louise Vatonne, Ve de Marie Eusèbe Maxime) dt à Billancourt, route de \nVersailles, 128, à Eugène Vatrin et Marceline Freling, dt à Billancourt, rue Nationale 31, de 21 303,88\nGauthier (par Marie Alexandrine) à Paris, rue St Ferdinand 2, à ses père et mère\nCusson (par Georges Ernest Léon) dt à Paris, rue Lamarck 144, à son père\nLecrosnier (ct livret de caisse d’Epargne de Paris, de 157,19 au nom de Pierre\nAuguste) décédé en son domicile à Paris, rue Descartes 21, le 16 8bre 1900\nLettéron (ct les prénoms de Louis Emile) décédé en son dom. à Villeneuve-St Georges, le 15 7bre 1897\nDupont (par Léonie Albertine Octavie) rue St-Lazare 82, à Honoré Bouscarat et sa\nfemme, à Montelaux (Aveyron) et à Achille Dareau, rue Guyot 17 de boutique aud. lieu\nde Lecanta y Mendieta (ct Joaquina Dolores Conception de Orbeta y\nAlguirre Ve Manuel), décédée à Bilbat, 23 calle de Btodebarriéta le 25 Mai 1900\nThéoule (par Alfred Sylvain Georges) dt à Paris, rue Bracq, 4, à sa mère\nde Neufville (par Jacob Guillaume) dt à Paris, rue Halévy 6, de valeurs dotales appt à Mme de Boissieux\nde Morangiès (de Marie Gertrude Oboril, épouse de Clodomir Albert) dt à\nParis, rue du Printemps, 22\n- d° - (dud. état)\nSté Block frères et Cie (par la Sté) siège à Toul, à Gabriel Henri Coujat,\nrue du Printemps 7, de 7.875+\nHenry (par Augustine Victoire Lecharpentier, épouse de Jean-Baptiste) à Paris,\nrue d’Athènes, 24, au mariage de sa fille\nMoreau Simond (par Gustave Arthur Félix) et Marie Françoise Pellerin ;\nEpx à Paris rue des Batignolles 76, pr vendre immeuble\nHarant (par Marthe Caroline Duval, rue Pigalle 11b, Ve de Alexandre Victor Armand) \nà Joseph Eugène Bogel et Marie Adelphine Julien, à Asnières, rue de Châteaudun 22, pr 10000+ px de vente \nPrat (ct livret de caisse des retraites pour la vieillesse , 150 + au nom de Jean\nJoseph) décédé en son dom. à Paris, rue de l’Annonciation 28, le 23 8bre 1900\nBoudon (de Pauline Antoinette Meyer, veen 1eres noces de Alexandre Chatel et en 2es\nnoces de François) décédé en son dom. à Paris, rue de Courcelles 192, le 21 février 1901\nde Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à Juan Mariano\nCte de Guagui, Mis de Villafuerte, même adresse, pr acq. de la Sté des Coteaux de Longchamps\nSté des locomotives sans foyer (ct la) par Léon Francq, à Paris \n48 avenue Victor Hugo\nLebedel (de Albéric Jean-Baptiste) à Paris, avenue Victoria 17, et Lucie Augustine \nHenry, à Paris rue d’Athènes 24 (communauté réduites aux acquêts)\nde Goyenèche (par Juan Mariano de Goyenèche y Gannio comte de Guagui,\ndt à Paris avenue de Friedland 15, et autres\nde Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à la Sté Fse des Coteaux du\nBois de Boulogne et de Longchamps, siège à Paris rue de l’Isly 9,  de 3 parcelles de terrain moyt 189585+\nGuille Stevens Le Marchant (ct titre de 396+ de rente 3% au nom de) Henri, dt à\nGrumbanck Croconhill Plymouth Conté de Devon (Angleterre) décédé le 9 mai 1900 à Sadysmith\nKnaier (par Françoise Rouchard, épouse de Alphonse), rue Laferrière 17, pr retirer \ntoutes sommes de la Caisse d’Epargne postale\nDutrey (par Marguerite Elvire Herneis, épouse de Jean Victor) dt à Paris, rue \nLegendre 176, pr recueillir S Son\nManot (par Engrace Millacet, épouse de Pierre) dt à Paris, rue de Grenelle,\n55, à M. Pillard, clerc\nFournié (après décès de Marie Muller, Ve de Marcelin) décédée en son domicile à\nParis, rue Beuret 20, le 11 février 1901\nTeil (par le ...

# %% [markdown]
# On instancie l'objet nlp avec notre échantillon. Cet objet est une pipeline de NLP dont les différentes étape peuvent être affichées ainsi :

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f392000e590>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x7f391ffcad10>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f39200331c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f3920093a60>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f39200bab40>),
#  ('lemmatizer', <spacy.lang.fr.lemmatizer.FrenchLemmatizer at 0x7f39200bf900>)]

# %%
doc = nlp(sample_norm)

# %% [markdown]
# On observe comment le modèle segmente les phrases (non-existantes) du texte, ou plutôt comment il essaye de redonner une structure logique.

# %%
for sent in doc.sents:
    print(sent.text)
    print("\n")
# Out:
# An 1901 , mois de Février
# Dupuis, (par Pierre) à Paris, rue Turgot 4, à Catherine Bizial, sa femme
# - d° - (par Mme)
#
#
# s.
#
#
# n. à son mari
# Murel (par Paul Louis Georges) dt à Paris, Bd
#
#
# Rochechouart 68, et Marie Joséphine
# Lemaire, dt à Paris, même adresse (
#
#
# Séparation de biens)
#
#
#
# Dubosc (ct titre de 380+ de rente 3% au nom  de : Debuisson, Justine Adèle,
# Vve de Jules) et autres, à Paris, rue de l’Arcade 20
#
#
#
# Rouy (par Edmond Narcisse), dt à Paris, rue Cavalotti 15, et autres, pr toucher &amp;
#
#
# recevoir
# Chabrol (par Marie Louise Vatonne, Ve de Marie Eusèbe Maxime) dt à Billancourt, route de
# Versailles, 128, à Eugène Vatrin et Marceline Freling, dt à Billancourt, rue Nationale 31, de 21 303,88
#
#
#
# Gauthier (par Marie Alexandrine) à Paris, rue St Ferdinand 2, à ses père et mère
# Cusson (par Georges Ernest Léon) dt à Paris, rue Lamarck 144, à son père
# Lecrosnier (ct livret de caisse d’Epargne de Paris, de 157,19 au nom de Pierre
# Auguste) décédé en son domicile à Paris, rue
#
#
# Descartes
#
#
# 21
#
#
# , le 16 8bre 1900
# Lettéron (ct les prénoms de Louis Emile) décédé en son dom.
#
#
# à Villeneuve-St Georges, le 15 7bre 1897
# Dupont (par Léonie Albertine Octavie) rue St-Lazare 82, à Honoré Bouscarat et sa
# femme, à Montelaux (Aveyron) et à Achille Dareau, rue Guyot 17 de boutique aud. lieu
# de Lecanta y Mendieta (ct Joaquina Dolores
#
#
# Conception de Orbeta y
#
#
#
# Alguirre
#
#
# Ve Manuel), décédée à Bilbat, 23 calle de Btodebarriéta le 25 Mai 1900
# Théoule (par Alfred Sylvain Georges)
#
#
# dt à Paris, rue Bracq, 4, à sa mère
# de Neufville (par Jacob Guillaume) dt à Paris, rue Halévy 6, de valeurs dotales appt à Mme de Boissieux
# de Morangiès (de Marie Gertrude Oboril, épouse de Clodomir Albert) dt à
# Paris, rue du Printemps, 22
# - d° - (dud. état)
# Sté Block frères et Cie (par la Sté) siège à Toul, à Gabriel Henri Coujat,
# rue du Printemps 7, de 7.875+
# Henry (par Augustine Victoire Lecharpentier, épouse de Jean-Baptiste) à Paris,
# rue d’Athènes, 24, au mariage de sa fille
# Moreau Simond (par Gustave Arthur Félix) et Marie Françoise Pellerin ;
#
#
#
#
#
#
# Epx à Paris rue des Batignolles 76, pr vendre immeuble
#
#
#
#
#
#
# Harant (par Marthe Caroline Duval, rue Pigalle 11b, Ve de Alexandre Victor Armand)
# à Joseph Eugène Bogel et Marie Adelphine Julien, à Asnières, rue de Châteaudun 22, pr 10000+ px de vente
# Prat (ct livret de caisse des retraites pour la vieillesse , 150 + au nom de Jean
# Joseph) décédé en son dom.
#
#
# à Paris, rue de l’Annonciation 28, le 23 8bre 1900
# Boudon (de Pauline Antoinette Meyer, veen 1eres noces de Alexandre Chatel et en 2es
# noces de François) décédé en son dom.
#
#
# à Paris, rue de Courcelles 192, le 21 février 1901
# de Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à Juan Mariano
# Cte de Guagui, Mis de Villafuerte, même adresse, pr acq.
#
#
# de la Sté des Coteaux de Longchamps
#
#
#
# Sté des locomotives sans foyer (ct la)
#
#
# par Léon Francq, à Paris
# 48 avenue Victor Hugo
# Lebedel (de Albéric Jean-Baptiste) à Paris, avenue Victoria 17, et Lucie Augustine
# Henry, à Paris rue d’Athènes 24 (communauté réduites aux acquêts)
#
#
#
# de Goyenèche
#
#
# (par Juan Mariano de Goyenèche y Gannio comte de Guagui,
# dt à Paris avenue de Friedland 15, et autres
# de Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à la Sté Fse des Coteaux du
# Bois de Boulogne et de Longchamps, siège à Paris rue de l’Isly 9,  de 3 parcelles de terrain moyt 189585+
#
#
#
# Guille
#
#
# Stevens
#
#
# Le Marchant (ct titre de 396+ de rente 3% au nom de) Henri, dt à
# Grumbanck Croconhill Plymouth Conté de Devon (Angleterre) décédé le 9 mai 1900 à Sadysmith
# Knaier (par Françoise Rouchard, épouse de Alphonse), rue Laferrière 17, pr retirer
# toutes sommes de la Caisse d’Epargne postale
# Dutrey (par Marguerite Elvire Herneis, épouse de Jean Victor) dt à Paris, rue
# Legendre 176, pr recueillir S Son
# Manot (par Engrace Millacet, épouse de Pierre) dt à Paris, rue de Grenelle,
# 55, à M. Pillard, clerc
# Fournié (après décès de Marie Muller, Ve de Marcelin) décédée en son domicile à
# Paris, rue Beuret 20, le 11 février 1901
# Teil (par le Crédit foncier à François) dt à Bois Colombes, villa Schutz, 13,
#
#
# de 22.000+

# %% [markdown]
# On utilise displacy pour avoir une représentation des POS de l'échantillon, toujours pour voir s'il y a une structure syntaxique exploitable.

# %%
# Import the displacy package
from spacy import displacy

# Add some options to display it nicely
options = {"compact": True, "distance": 200, "color": "green"}

# Pass the excert document to displacy to display
displacy.render(doc, options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="a6fee9281d284321a27f8c56db132405-0" class="displacy" width="156450" height="4337.0" direction="ltr" style="max-width: none; height: 4337.0px; color: green; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">An</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">1901 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">mois</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Février</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Dupuis, (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">Pierre)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Paris,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">rue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Turgot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">4,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Catherine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3250">Bizial,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3450">sa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">femme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3850">
# -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4050">d° - (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4450">Mme)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4650">s.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4650">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4850">n.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4850">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5050">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5250">son</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5450">mari</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5650">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5650">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5850">Murel (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="4247.0">
#     <tspan class="displacy-word" fill="currentColor" x="6050">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill

# %% [markdown]
# D'emblée, problème apparent : difficulté de la reconstruction syntaxique à cause de la récupération de l'intégralité de la transcription, sans distinction des colonnes du document originel.

# %% [markdown]
# On affiche les entités récupérées automatiquement dans le texte sous la forme suivante :
#
# `token: label de l'entité`

# %%
for entity in doc.ents:
    print(f'{entity.text}: {entity.label_}')
# Out:
# An 1901: MISC
# Février
# Dupuis: ORG
# Pierre: MISC
# Paris: LOC
# rue Turgot: LOC
# Catherine Bizial: PER
# Mme: PER
# Murel: MISC
# Paul Louis Georges: PER
# Paris: LOC
# Marie Joséphine
# Lemaire: PER
# Paris: LOC
# Séparation: MISC
# Dubosc: PER
# Debuisson: PER
# Justine Adèle: PER
# Vve de Jules: PER
# Paris: LOC
# rue de l’Arcade 20
# : LOC
# Rouy: LOC
# Edmond Narcisse: PER
# Paris: LOC
# Cavalotti 15: MISC
# Chabrol: PER
# Marie Louise Vatonne: PER
# Ve: LOC
# Marie Eusèbe Maxime: PER
# Billancourt: LOC
# Versailles: LOC
# Eugène Vatrin: PER
# Marceline Freling: PER
# Billancourt: LOC
# rue Nationale 31: LOC
# Gauthier: PER
# Marie Alexandrine: PER
# Paris: LOC
# rue St Ferdinand 2: LOC
# Cusson: PER
# Georges Ernest Léon: PER
# Paris: LOC
# Lamarck: PER
# Lecrosnier: PER
# Epargne de Paris: MISC
# Pierre
# Auguste: PER
# Paris: LOC
# Descartes: PER
# Louis Emile: PER
# Villeneuve-St Georges: MISC
# Dupont: PER
# Léonie Albertine Octavie: PER
# rue St: LOC
# Lazare: LOC
# Honoré Bouscarat: PER
# Montelaux: LOC
# Aveyron: LOC
# Achille Dareau: PER
# Guyot: PER
# Lecanta y Mendieta: PER
# Joaquina Dolores: MISC
# Bilbat: LOC
# calle de Btodebarriéta: LOC
# Théoule: LOC
# Alfred Sylvain Georges: PER
# Paris: LOC
# rue Bracq: LOC
# Neufville: PER
# Jacob Guillaume: PER
# Paris: LOC
# Halévy: PER
# Mme de Boissieux: PER
# Morangiès: LOC
# Marie Gertrude Oboril: PER
# Clodomir Albert: PER
# Paris: LOC
# rue du Printemps: LOC
# Sté Block frères: MISC
# Cie: MISC
# Sté: ORG
# Toul: LOC
# Gabriel Henri Coujat: PER
# Printemps 7: MISC
# Henry: PER
# Augustine Victoire Lecharpentier: PER
# Jean-Baptiste: PER
# Paris: LOC
# Athènes: LOC
# Moreau Simond: PER
# Gustave Arthur Félix: PER
# Marie Françoise Pellerin: PER
# Epx: LOC
# Paris: LOC
# Harant: PER
# Marthe Caroline Duval: PER
# rue Pigalle 11b: LOC
# Ve: LOC
# Alexandre Victor Armand: PER
# Joseph Eugène Bogel: PER
# Marie Adelphine Julien: PER
# Asnières: LOC
# Châteaudun: LOC
# Prat: PER
# Jean
# Joseph: PER
# Paris: LOC
# rue de l’: LOC
# Annonciation 28: MISC
# Boudon: PER
# Pauline Antoinette Meyer: PER
# Alexandre Chatel: PER
# François: PER
# Paris: LOC
# Courcelles: LOC
# Goyenèche: LOC
# Carmen: PER
# Paris: LOC
# Juan Mariano
# Cte de Guagui: PER
# Villafuerte: PER
# Sté des Coteaux de Longchamps: ORG
# Sté: ORG
# Léon Francq: PER
# Paris: LOC
# Victor Hugo
# Lebedel: PER
# Albéric Jean-Baptiste: PER
# Paris: LOC
# Lucie Augustine
# Henry: PER
# Paris: LOC
# Athènes 24: LOC
# Goyenèche: LOC
# Juan Mariano de Goyenèche: PER
# Gannio: LOC
# Paris: LOC
# Goyenèche: LOC
# Carmen: PER
# Paris: LOC
# Sté Fse des Coteaux du
# Bois de Boulogne: ORG
# Longchamps: LOC
# Paris: LOC
# rue de l’Isly 9: LOC
# Guille: PER
# Le Marchant: MISC
# Henri: PER
# Grumbanck Croconhill Plymouth Conté de Devon: MISC
# Angleterre: LOC
# Sadysmith
# Knaier: PER
# Françoise Rouchard: PER
# Alphonse: PER
# Caisse d’Epargne postale: ORG
# Dutrey: PER
# Marguerite Elvire Herneis: PER
# Jean Victor: PER
# Paris: LOC
# rue
# Legendre: LOC
# S: LOC
# Manot: LOC
# Engrace Millacet: PER
# Pierre: MISC
# Paris: LOC
# rue de Grenelle: LOC
# M. Pillard: PER
# Fournié: PER
# Marie Muller: PER
# Ve de Marcelin: PER
# Paris: LOC
# rue Beuret 20: LOC
# Teil: LOC
# Crédit foncier: ORG
# François: PER
# Bois Colombes: LOC
# Schutz: PER

# %% [markdown]
# # Rule-based matching

# %% [markdown]
# Il est possible de récupérer des entités non détectées en constituant des règles. Nous essayons cette solution sur un autre échantillon transcrit manuellement dans le cadre du projet Lectaurep, dont la segmentation n'a pas été modifié : toute la page a été gardée.
#
# Nous constituerons ces règles à partir des référentiels fournis par les Archives Nationals :
# * Mots matières
# * Types documents

# %%
with open("../../corpus_test/lectaurep/spaCy_bac_a_sable/sample_doc53_central_column.txt", 'r', encoding='utf-8') as file:
    sample_2 = file.read()

# %%
sample_without_breaks_2 = sample_2.replace('\n', ' ')
# On utilise une regex pour ajouter un espace avant les majuscules
sample_norm_2 = re.sub(r"(\w)([A-Z])", r"\1 \2", sample_without_breaks_2)

# %%
doc_2 = nlp(sample_norm_2)

# %% [markdown]
# On commence par récupérer les mots matières.

# %%
with open("../../corpus_test/lectaurep/spaCy_bac_a_sable/referentiels/FRAN_RI_004_motsMatieres.tsv", 'r') as file:
    referentiel_mots_matieres = csv.reader(file, delimiter="\t")
    # On récupère la colonne Terme
    mots_matieres = [i[1:2] for i in referentiel_mots_matieres]
    # On retire le header
    mots_matieres = mots_matieres[1:]
    
mots_matieres
# Out:
# [['1% artistique'],
#  ['abattage'],
#  ['abattoir'],
#  ['abbaye'],
#  ['absence'],
#  ['abstention'],
#  ['académie'],
#  ["accès à l'eau"],
#  ['accession à la propriété'],
#  ["accident d'avion"],
#  ['accident de la circulation'],
#  ['accident du travail'],
#  ['accident scolaire'],
#  ['accord bilatéral'],
#  ['accord commercial'],
#  ['accord de défense'],
#  ['accord économique'],
#  ['accord international'],
#  ['accord salarial'],
#  ["accords d'Evian (1962)"],
#  ['acheminement postal'],
#  ['acier'],
#  ['Acte additionnel de 1815'],
#  ['acte administratif'],
#  ['Acte unique européen (1986)'],
#  ['action concertée'],
#  ['action culturelle'],
#  ['action humanitaire'],
#  ['actionnaire'],
#  ['actionnariat salarié'],
#  ['action publique'],
#  ['action sociale'],
#  ['action thématique programmée'],
#  ['activité parlementaire'],
#  ['activité périscolaire'],
#  ['activité socio-éducative'],
#  ["adduction d'eau"],
#  ['adjudication'],
#  ['administration après 1789'],
#  ['administration centrale'],
#  ['administration pénitentiaire'],
#  ['adolescence'],
#  ['adoption'],
#  ['adulte'],
#  ['aéroclub'],
#  ['aérodrome'],
#  ['aéroglisseur'],
#  ['aéroport'],
#  ['aérostat'],
#  ['aérotrain'],
#  ['affaire civile'],
#  ['affaire Lip (1973-1976)'],
#  ['affaire pénale'],
#  ['affaire politico-judiciaire'],
#  ['affaire réservée'],
#  ['affermage'],
#  ['affiliation'],
#  ['âge de la retraite'],
#  ["agence d'urbanisme"],
#  ['agence de presse'],
#  ['agence de voyages'],
#  ['agence régionale de santé'],
#  ['agglomération'],
#  ['agrégation'],
#  ['agression sexuelle'],
#  ['agriculture'],
#  ['agriculture biologique'],
#  ['agroalimentaire'],
#  ['agronomie'],
#  ['aide à la recherche'],
#  ['aide à la scolarité'],
#  ['aide alimentaire'],
#  ['aide au développement'],
#  ['aide au logement'],
#  ['aide au retour'],
#  ["aide de l'Etat"],
#  ['aide judiciaire'],
#  ["aide médicale d'Etat"],
#  ['aide sociale'],
#  ["aide sociale à l'enfance"],
#  ['alcool'],
#  ['alcoolisme'],
#  ['algue'],
#  ['aliénation'],
#  ['alimentation'],
#  ['alimentation animale'],
#  ['allocation de logement'],
#  ['allocation de recherche'],
#  ['allocation familiale'],
#  ['alpinisme'],
#  ['alsacien-lorrain'],
#  ['alsacien-mosellan'],
#  ['alternance'],
#  ['aluminium'],
#  ['ambassade'],
#  ["amélioration de l'habitat"],
#  ["aménagement des cours d'eau"],
#  ['aménagement du temps'],
#  ['aménagement du territoire'],
#  ['aménagement foncier'],
#  ['aménagement forestier'],
#  ['aménagement rural'],
#  ['amende'],
#  ['amendement'],
#  ['ameublement'],
#  ['amiante'],
#  ['amnistie'],
#  ['analyse médicale'],
#  ['anarchisme'],
#  ['anarchisme (Première République)'],
#  ['ancien combattant'],
#  ['animal domestique'],
#  ['animal nuisible'],
#  ['animation socio-culturelle'],
#  ['annulation de mariage'],
#  ['anoblissement'],
#  ['anticléricalisme'],
#  ['anticommunisme'],
#  ['antifascisme'],
#  ['antimilitarisme'],
#  ['antiparlementarisme'],
#  ['antisémitisme'],
#  ['apartheid'],
#  ['apatride'],
#  ['appareillage'],
#  ["appariement d'établissement"],
#  ['appelé'],
#  ['application des peines'],
#  ['application du droit communautaire'],
#  ['apprentissage'],
#  ['apprentissage maritime'],
#  ['aquaculture'],
#  ['aqueduc'],
#  ['arboriculture'],
#  ['arbre fruitier'],
#  ['archéologie'],
#  ['architecture'],
#  ['archives'],
#  ['arme'],
#  ['Arme blindée cavalerie'],
#  ['armée'],
#  ["armée de l'air"],
#  ['armée de métier'],
#  ['armée de terre'],
#  ['armée étrangère'],
#  ['armement'],
#  ['armement conventionnel'],
#  ['armement maritime'],
#  ['armement nucléaire, biologique, chimique'],
#  ['armistice'],
#  ['armoiries'],
#  ['arrestation'],
#  ['arrondissement'],
#  ['arsenal'],
#  ['Artillerie'],
#  ['artisan'],
#  ['artisanat'],
#  ['arts appliqués'],
#  ['arts et lettres'],
#  ['arts graphiques'],
#  ['arts plastiques'],
#  ['asile politique'],
#  ['assainissement'],
#  ['assassinat politique'],
#  ['assemblée constituante'],
#  ['association'],
#  ['association cultuelle'],
#  ['association foncière urbaine'],
#  ['association syndicale de propriétaires'],
#  ['assurance'],
#  ['assurance maladie'],
#  ['assurance sociale'],
#  ['assurance vieillesse'],
#  ['astronomie'],
#  ["atelier d'artiste"],
#  ['athlète de haut-niveau'],
#  ['athlétisme'],
#  ['atmosphère'],
#  ['attentat'],
#  ['audiovisuel'],
#  ['auditorium'],
#  ['autobus'],
#  ['autocar'],
#  ['auto-école'],
#  ['automobile'],
#  ['autonomisme'],
#  ['autorisation de programme'],
#  ["autorisation de servir à l'étranger"],
#  ['autorisation de transport'],
#  ['autorité administrative indépendante'],
#  ['autorité parentale'],
#  ['autoroute'],
#  ['avalanche'],
#  ['aviation civile'],
#  ['aviation légère'],
#  ["Aviation légère de l'armée de terre"],
#  ['aviation militaire'],
#  ['aviculture'],
#  ['avion'],
#  ['avion Airbus'],
#  ['avion Concorde'],
#  ['avion de combat'],
#  ['avortement'],
#  ['bac'],
#  ['baccalauréat'],
#  ['bail'],
#  ['bail rural'],
#  ['balise'],
#  ['ballet'],
#  ['banane'],
#  ['bande dessinée'],
#  ['banditisme'],
#  ['banlieue'],
#  ['banque'],
#  ['banque de données'],
#  ['barrage'],
#  ['barricade'],
#  ['base aérienne'],
#  ['base de données'],
#  ['bassin hydrographique'],
#  ['bassin minier'],
#  ['bataillon'],
#  ['bateau'],
#  ['bateau de pêche'],
#  ['batellerie'],
#  ['bâtiment'],
#  ["bâtiment d'exploitation"],
#  ["bâtiment d'habitation"],
#  ['bâtiment militaire'],
#  ['bâtiment public'],
#  ['bauxite'],
#  ['bibliothèque'],
#  ['bibliothèque centrale de prêt'],
#  ['bibliothèque municipale'],
#  ['bibliothèque universitaire'],
#  ['bidonville'],
#  ["bien d'équipement"],
#  ['bien de consommation'],
#  ['bien immeuble'],
#  ['bien juif'],
#  ['bien meuble'],
#  ['biens nationaux'],
#  ['bijouterie'],
#  ['bilan législatif'],
#  ['bilinguisme'],
#  ['bioéthique'],
#  ['biologie'],
#  ['biologie médicale'],
#  ['biotechnologie'],
#  ['blanchiment'],
#  ['blanchisserie'],
#  ['blocus'],
#  ['bois'],
#  ['bois exotique'],
#  ['boisson'],
#  ['boisson alcoolisée'],
#  ['boisson non alcoolisée'],
#  ['bolchevisme'],
#  ['bombardement'],
#  ['bonapartisme'],
#  ['bon du trésor'],
#  ['boucherie'],
#  ['boulangisme'],
#  ['boulevard'],
#  ['bourse'],
#  ["bourse d'étude"],
#  ['bourse de recherche'],
#  ['bovin'],
#  ["brevet d'invention"],
#  ['brevet de technicien supérieur'],
#  ['brevet professionnel'],
#  ['brigade'],
#  ['brucellose'],
#  ['bruit'],
#  ['budget'],
#  ["budget de l'Etat"],
#  ['budget de programme'],
#  ['bureau de placement'],
#  ['bureau de poste'],
#  ['bureautique'],
#  ['cabinet ministériel'],
#  ['cabotage'],
#  ['cacao'],
#  ['cadastre'],
#  ['café'],
#  ['calamité agricole'],
#  ["campagne d'information"],
#  ['campagne électorale'],
#  ["camp d'internement"],
#  ['camp de concentration'],
#  ['camp de prisonniers'],
#  ['camping'],
#  ['canal'],
#  ['canalisation'],
#  ['cancer'],
#  ['candidature'],
#  ['cantine scolaire'],
#  ['canton'],
#  ['caoutchouc'],
#  ['caprin'],
#  ['captage'],
#  ['carburant'],
#  ['cargo'],
#  ['carrière'],
#  ['carrière professionnelle'],
#  ["carte d'identité"],
#  ['carte de travail'],
#  ['carte judiciaire'],
#  ['carte scolaire'],
#  ['cartographie'],
#  ['caserne'],
#  ['casier judiciaire'],
#  ['casino'],
#  ['catastrophe de Tchernobyl (1986)'],
#  ['catastrophe industrielle'],
#  ['catastrophe minière'],
#  ['catastrophe naturelle'],
#  ['catastrophes et accidents'],
#  ['catastrophes et accidents en France'],
#  ['catastrophes et accidents hors de France'],
#  ['catégorie socio-professionnelle'],
#  ['catholicisme'],
#  ['célébration nationale'],
#  ['censure'],
#  ['Cent-Jours'],
#  ['centrale hydro-électrique'],
#  ['centrale nucléaire'],
#  ['centrale thermique'],
#  ['centre'],
#  ['centre commercial'],
#  ['centre culturel'],
#  ['centre culturel de rencontre'],
#  ["centre d'action culturelle"],
#  ["centre d'information et d'orientation"],
#  ['centre de formation'],
#  ["centre de formation d'apprentis"],
#  ['centre de tri'],
#  ['centre de vacances'],
#  ['centre équestre'],
#  ['centre hospitalier régional'],
#  ['centre hospitalier universitaire'],
#  ['centre-ville'],
#  ['cercle de jeu'],
#  ['céréale'],
#  ['cérémonie'],
#  ["certificat d'aptitude"],
#  ["certificat d'aptitude au professorat d'éducation physique et sportive"],
#  ["certificat d'aptitude au professorat de l'enseignement secondaire"],
#  ["certificat d'aptitude au professorat de l'enseignement technique"],
#  ["certificat d'aptitude pédagogique"],
#  ["certificat d'aptitude professionnelle"],
#  ["certificat d'études primaires"],
#  ['cessez-le-feu'],
#  ["chambre d'agriculture"],
#  ["chambre de commerce et d'industrie"],
#  ['chambre de métiers'],
#  ['change'],
#  ['changement climatique'],
#  ['changement de nom'],
#  ['chanson'],
#  ['chant'],
#  ['chantier de la jeunesse'],
#  ['chantier de travaux publics'],
#  ['chantier naval'],
#  ['chapelle'],
#  ['charbon'],
#  ['charge salariale'],
#  ['Charte constitutionnelle de 1814'],
#  ['Charte constitutionnelle de 1830'],
#  ['chasse'],
#  ['chasse présidentielle'],
#  ['château'],
#  ["château d'eau"],
#  ['château fort'],
#  ['chauffage'],
#  ['chaussée'],
#  ['chaussure'],
#  ['chemin de fer'],
#  ['chemin de fer industriel'],
#  ['cheptel'],
#  ['chèque vacances'],
#  ['cheval'],
#  ['chimie'],
#  ['chimie fine'],
#  ['chirurgie dentaire'],
#  ['chômage'],
#  ['christianisme orthodoxe'],
#  ['cimetière'],
#  ['cimetière militaire'],
#  ['cinéma'],
#  ['cinémathèque'],
#  ['Cinquième République'],
#  ['circonscription électorale'],
#  ['circonscription révolutionnaire'],
#  ['circonscription territoriale'],
#  ['circulation routière'],
#  ['cirque'],
#  ["cité d'urgence"],
#  ['citoyenneté'],
#  ['civisme'],
#  ['classe préparatoire aux grandes écoles'],
#  ['classe transplantée'],
#  ['clergé'],
#  ['cléricalisme'],
#  ['climat'],
#  ['climatologie'],
#  ['clôture du budget'],
#  ['club de jeunes'],
#  ["coche d'eau"],
#  ['code civil'],
#  ['code de la route'],
#  ['code du travail'],
#  ['code minier'],
#  ['code pénal'],
#  ['cohabitation'],
#  ['collaborateur'],
#  ['collaboration'],
#  ['collection'],
#  ["collectivité d'outre-mer"],
#  ['collectivité territoriale'],
#  ['collège'],
#  ['colloque'],
#  ['colonialisme'],
#  ['colonie'],
#  ['colonie de vacances'],
#  ['colonisation'],
#  ['combustible'],
#  ["comité d'entreprise"],
#  ["comité d'hygiène, de sécurité et des conditions de travail"],
#  ['Comité français de la Libération nationale'],
#  ['comité interministériel'],
#  ['comité technique paritaire'],
#  ['commandement militaire'],
#  ['commande publique'],
#  ['commémoration'],
#  ['commerce'],
#  ['commerce ambulant'],
#  ["commerce d'armes"],
#  ['commerce de détail'],
#  ['commerce de gros'],
#  ['commerce extérieur'],
#  ['commerce international'],
#  ['commercialisation'],
#  ['commissariat de police'],
#  ['commission administrative paritaire'],
#  ["commission d'hygiène industrielle"],
#  ['commission paritaire'],
#  ['commission parlementaire'],
#  ['commission scientifique'],
#  ['communautarisme'],
#  ['communauté juive'],
#  ['commune'],
#  ['commune sinistrée'],
#  ['communication'],
#  ['communication de crise'],
#  ['communication interne'],
#  ['communisme'],
#  ['compagnie aérienne'],
#  ['compagnie chorégraphique'],
#  ['compagnie de chemin de fer'],
#  ['compagnie maritime'],
#  ['compagnie théâtrale'],
#  ['compétence juridictionnelle'],
#  ['compétition sportive'],
#  ['compétitivité'],
#  ['complot'],
#  ['composition du gouvernement'],
#  ['comptabilité publique'],
#  ['comptes de la nation'],
#  ['comptes départementaux'],
#  ["concentration d'entreprises"],
#  ['concert'],
#  ['concession'],
#  ['conchyliculture'],
#  ['Concordat (1801)'],
#  ['concours'],
#  ["concours financier de l'Etat"],
#  ['concours général'],
#  ['concurrence'],
#  ['condition féminine'],
#  ['conditionnement'],
#  ['conditions de travail'],
#  ['conditions de vie'],
#  ['conduite automobile'],
#  ['confédération'],
#  ['conférence'],
#  ['conférence de presse'],
#  ['conférence internationale'],
#  ['conflit du travail'],
#  ['conflit international'],
#  ['conflits et guerres'],
#  ['congé'],
#  ['congé payé'],
#  ['congrégation religieuse'],
#  ['congrès'],
#  ['conjoncture économique'],
#  ["conquête de l'Algérie (1829-1840)"],
#  ["conseil d'administration"],
#  ["conseil d'arrondissement"],
#  ["conseil d'école"],
#  ['conseil de classe'],
#  ['conseil de préfecture'],
#  ["conseil de prud'hommes"],
#  ['conseil des ministres'],
#  ['conseil général'],
#  ['conseil interministériel'],
#  ['conseil municipal'],
#  ['conseil régional'],
#  ['conservatisme'],
#  ['conserve'],
#  ['consistoire'],
#  ['consommation'],
#  ['constitution'],
#  ['Constitution de 1791'],
#  ['Constitution de 1793'],
#  ['Constitution de 1795'],
#  ['Constitution de 1799'],
#  ['Constitution de 1802'],
#  ['Constitution de 1804'],
#  ['Constitution de 1848'],
#  ['Constitution de 1852'],
#  ['Constitution de 1875'],
#  ['Constitution de 1946'],
#  ['Constitution de 1958'],
#  ['constitutionnalisme'],
#  ['construction'],
#  ['construction aéronautique'],
#  ['construction aérospatiale'],
#  ['construction automobile'],
#  ['construction européenne'],
#  ['construction hospitalière'],
#  ['construction navale'],
#  ['construction provisoire'],
#  ['construction scolaire'],
#  ['construction universitaire'],
#  ['consulat'],
#  ['Consulat (1799-1802)'],
#  ['Consulat à vie'],
#  ['conteneur'],
#  ['contentieux'],
#  ['contentieux administratif'],
#  ['contexte historique'],
#  ['contingent'],
#  ['contingentement'],
#  ['continuité territoriale'],
#  ['contraception'],
#  ['contrat de pays'],
#  ['contrat de plan'],
#  ['contrat de travail'],
#  ['contrat de ville'],
#  ['contribution économique territoriale'],
#  ['contribution foncière'],
#  ['contribution personnelle mobilière'],
#  ['contribution sociale généralisée'],
#  ['contrôle aérien'],
#  ['contrôle aux frontières'],
#  ["contrôle d'identité"],
#  ['contrôle financier'],
#  ['contrôle parlementaire'],
#  ['contrôle sanitaire'],
#  ['convention collective'],
#  ['convention culturelle'],
#  ['Convention de Schengen (1985)'],
#  ['convention médicale'],
#  ['Convention nationale'],
#  ['coopérant'],
#  ['coopération'],
#  ['coopération culturelle'],
#  ['coopération économique'],
#  ['coopération intercommunale'],
#  ['coopération militaire'],
#  ['coopération scientifique'],
#  ['coopérative'],
#  ['coopérative rurale'],
#  ['coordination des transports'],
#  ['coquillage'],
#  ['corruption'],
#  ['cotisation sociale'],
#  ['coup d’état'],
#  ["cour administrative d'appel"],
#  ["cour d'appel"],
#  ["cour d'assises"],
#  ['cour prévôtale'],
#  ['courrier'],
#  ["cours d'eau"],
#  ['course'],
#  ['course de lévriers'],
#  ['course hippique'],
#  ['coût'],
#  ['coût de la santé'],
#  ['couverture maladie universelle'],
#  ['création artistique'],
#  ['création audiovisuelle'],
#  ["création d'entreprise"],
#  ['crédit'],
#  ['crime'],
#  ["crime contre l'humanité"],
#  ['crime de guerre'],
#  ['criminalité'],
#  ['crise de Suez (1956)'],
#  ['crise économique et financière'],
#  ['crise politique'],
#  ['croix'],
#  ['crustacé'],
#  ['cuir'],
#  ['cuivre'],
#  ['culte'],
#  ['culture'],
#  ['culture scientifique'],
#  ['cumul des mandats'],
#  ['cycles et motocycles'],
#  ['cyclisme'],
#  ['cyclone'],
#  ['danse'],
#  ['débarquement'],
#  ['débat parlementaire'],
#  ['débit de boissons'],
#  ['débit de tabac'],
#  ['décentralisation'],
#  ['décentralisation industrielle'],
#  ['décès'],
#  ['déchet'],
#  ['déchet industriel'],
#  ['déchet nucléaire'],
#  ["déclaration d'utilité publique"],
#  ['déclaration de politique générale'],
#  ["déclaration des droits de l'homme"],
#  ['décolonisation'],
#  ['déconcentration'],
#  ['décoration'],
#  ['décret'],
#  ['décret-loi'],
#  ['défense'],
#  ['défense aérienne'],
#  ['défense civile'],
#  ['défense contre avions'],
#  ['défense contre la mer'],
#  ['défense européenne'],
#  ['déficit budgétaire'],
#  ['défrichement'],
#  ['délimitation de frontière'],
#  ['délinquance'],
#  ['délit'],
#  ['délocalisation administrative'],
#  ['délocalisation industrielle'],
#  ['démobilisation'],
#  ['démocrates-chrétiens'],
#  ['démocratie'],
#  ['démographie'],
#  ['démographie médicale'],
#  ['déontologie'],
#  ['département'],
#  ["département d'outre-mer"],
#  ["départements et collectivités d'outre-mer"],
#  ['dépendance'],
#  ["dépense d'équipement"],
#  ['dépense de fonctionnement'],
#  ['déplacement officiel'],
#  ['déportation'],
#  ['déporté'],
#  ["dépôt d'hydrocarbures"],
#  ['désarmement'],
#  ['désert'],
#  ['déserteur'],
#  ['désinfection'],
#  ['desserte'],
#  ['dessin'],
#  ['détenu'],
#  ['dette publique'],
#  ['Deuxième République'],
#  ['développement durable'],
#  ['développement économique'],
#  ['devise'],
#  ['dictature'],
#  ['digue'],
#  ['diplomatie'],
#  ['diplôme'],
#  ['diplôme national du brevet'],
#  ['diplôme sportif'],
#  ['diplôme universitaire'],
#  ['Directoire'],
#  ['discipline'],
#  ["discipline d'enseignement"],
#  ['discipline pénitentiaire'],
#  ['discipline sportive'],
#  ['discrimination sociale'],
#  ['dispensaire'],
#  ['dispense pour mariage'],
#  ["dispositif d'aide pédagogique"],
#  ['dissolution'],
#  ['distribution postale'],
#  ['district révolutionnaire'],
#  ['division'],
#  ['divorce'],
#  ['dock'],
#  ['doctorat'],
#  ['document administratif'],
#  ['documentation'],
#  ["document d'urbanisme"],
#  ['domaine privé'],
#  ['domaine public'],
#  ['domaine public des collectivités territoriales'],
#  ['domaine public fluvial'],
#  ['domaine public maritime'],
#  ['domaines'],
#  ['domicile'],
#  ['dommages de guerre'],
#  ['dons et legs'],
#  ["dotation globale d'équipement"],
#  ['dotation globale de fonctionnement'],
#  ['douane'],
#  ['drainage'],
#  ['droit'],
#  ['droit administratif'],
#  ['droit civil'],
#  ['droit commercial'],
#  ['droit communautaire'],
#  ['droit constitutionnel'],
#  ["droit d'asile"],
#  ["droit d'auteur"],
#  ["droit d'usage"],
#  ['droit de grâce'],
#  ['droit de la mer'],
#  ['droit de port'],
#  ['droit des personnes'],
#  ['droit de vote'],
#  ['droit du travail'],
#  ['droite'],
#  ['droit international'],
#  ['droit pénal'],
#  ['droit privé'],
#  ['droit public'],
#  ["droits d'enregistrement"],
#  ["droits de l'enfant"],
#  ["droits de l'homme"],
#  ['droits des femmes'],
#  ['droits de succession'],
#  ['droit syndical'],
#  ['dumping'],
#  ['durée du travail'],
#  ['eau'],
#  ['eau minérale'],
#  ['eau potable'],
#  ['eau souterraine'],
#  ['eaux territoriales'],
#  ['eaux usées'],
#  ['échange culturel'],
#  ['écluse'],
#  ['école de police'],
#  ['école maternelle'],
#  ['école militaire'],
#  ["école normale d'instituteurs"],
#  ['école primaire'],
#  ['écologie'],
#  ['écologisme'],
#  ['écomusée'],
#  ['économie'],
#  ['économie agricole'],
#  ["économie d'énergie"],
#  ['économie des transports'],
#  ['économie internationale'],
#  ['économie sociale et solidaire'],
#  ['écurie'],
#  ['édifice cultuel'],
#  ['édit'],
#  ['édition'],
#  ['éducation adaptée'],
#  ['éducation artistique'],
#  ['éducation physique et sportive'],
#  ['éducation populaire'],
#  ['éducation sanitaire'],
#  ['éducation sexuelle'],
#  ['effectif'],
#  ['effet de serre'],
#  ['égalité des chances'],
#  ['égalité professionnelle'],
#  ['église'],
#  ["élargissement de l'Union européenne"],
#  ['élargissement de la CEE'],
#  ['élection'],
#  ['élection aux assemblées communales'],
#  ['élection aux assemblées départementales'],
#  ['élection aux assemblées primaires'],
#  ['élection aux Etats généraux de 1789'],
#  ['élection cantonale'],
#  ['élection européenne'],
#  ['élection législative'],
#  ['élection municipale'],
#  ['élection partielle'],
#  ['élection présidentielle'],
#  ['élection professionnelle'],
#  ['élection provinciale'],
#  ["élection prud'homale"],
#  ['élection régionale'],
#  ['élection sénatoriale'],
#  ['électricité'],
#  ['électrification'],
#  ['électrification rurale'],
#  ['électroménager'],
#  ['électronique'],
#  ['élevage'],
#  ['éligibilité'],
#  ['embargo'],
#  ['émeute'],
#  ['émigration'],
#  ['empire'],
#  ['empire colonial'],
#  ['emploi'],
#  ['employeur'],
#  ['emprunt'],
#  ["emprunt d'Etat"],
#  ['enceinte'],
#  ['endettement'],
#  ['énergie'],
#  ['énergie éolienne'],
#  ['énergie marémotrice'],
#  ['énergie nucléaire'],
#  ['énergie renouvelable'],
#  ['énergie solaire'],
#  ['enfance'],
#  ['enfant'],
#  ['enfant en difficulté scolaire'],
#  ['engrais'],
#  ['enquête'],
#  ["enquête d'opinion"],
#  ['enquête publique'],
#  ['enseignement'],
#  ['enseignement à distance'],
#  ['enseignement agricole'],
#  ['enseignement artistique'],
#  ['enseignement élémentaire'],
#  ["enseignement français à l'étranger"],
#  ['enseignement maritime'],
#  ['enseignement ménager'],
#  ['enseignement par correspondance'],
#  ['enseignement préélémentaire'],
#  ['enseignement primaire'],
#  ['enseignement privé'],
#  ['enseignement professionnel'],
#  ['enseignement public'],
#  ['enseignement religieux'],
#  ['enseignement secondaire'],
#  ['enseignement supérieur'],
#  ['enseignement technique'],
#  ['ensemble vocal'],
#  ['entrepôt'],
#  ['entreprise'],
#  ['entreprise de transport'],
#  ['entreprise en difficulté'],
#  ['entreprise publique'],
#  ['environnement'],
#  ['épargne'],
#  ['épidémie'],
#  ['épidémiologie'],
#  ['épizootie'],
#  ['épuration administrative'],
#  ['équipement'],
#  ['équipement automobile'],
#  ['équipement culturel'],
#  ['équipement de loisir'],
#  ['équipement de protection'],
#  ['équipement énergétique'],
#  ['équipement sanitaire et social'],
#  ['équipement scolaire et universitaire'],
#  ['équipement socio-culturel'],
#  ['équipement sportif'],
#  ['équipement téléphonique'],
#  ['équipement touristique'],
#  ['équitation'],
#  ['équivalence de diplôme'],
#  ['éruption volcanique'],
#  ['escroquerie'],
#  ['espace'],
#  ['espace protégé'],
#  ['espace vert'],
#  ['essence'],
#  ['estuaire'],
#  ['établissement culturel'],
#  ["établissement d'enseignement"],
#  ["établissement d'enseignement artistique"],
#  ['établissement de santé'],
#  ['établissement national de bienfaisance'],
#  ['établissement pénitentiaire'],
#  ['établissement public'],
#  ['établissement public de coopération intercommunale'],
#  ['établissements et services sociaux et médico-sociaux'],
#  ['établissement thermal'],
#  ['étain'],
#  ['étalon monétaire'],
#  ['étang'],
#  ['état civil'],
#  ['état de siège'],
#  ['état d’urgence'],
#  ['Etat français'],
#  ['état-major'],
#  ["étendue d'eau"],
#  ['éthanol'],
#  ['éthique'],
#  ['ethnologie'],
#  ['étranger'],
#  ['étude'],
#  ['étude prospective'],
#  ['Euro'],
#  ['euthanasie'],
#  ['évasion'],
#  ['événements de Mai 1968'],
#  ['événements en France'],
#  ['événements hors de France'],
#  ['examen'],
#  ['exclusion sociale'],
#  ['exécution budgétaire'],
#  ['exercice comptable'],
#  ['exercice de défense'],
#  ['exhumation'],
#  ['exode rural'],
#  ['exode urbain'],
#  ['exonération fiscale'],
#  ['expédition scientifique'],
#  ['expérimentation'],
#  ['exploitation agricole'],
#  ['exploitation forestière'],
#  ['explosif'],
#  ['exportation'],
#  ['exposition'],
#  ['exposition commerciale'],
#  ['exposition universelle'],
#  ['expropriation'],
#  ['expulsion'],
#  ['extradition'],
#  ['extrême droite'],
#  ['extrême gauche'],
#  ["fabrique d'église"],
#  ['facture instrumentale'],
#  ['faculté'],
#  ['faillite'],
#  ['famille'],
#  ['famille monoparentale'],
#  ['fascisme'],
#  ['faune'],
#  ['faux-monnayage'],
#  ['fécondité'],
#  ['fédéralisme'],
#  ['fédération sportive'],
#  ['femme'],
#  ['fer'],
#  ['festival'],
#  ['fête nationale'],
#  ['feu de signalisation'],
#  ['fièvre aphteuse'],
#  ['filiation'],
#  ['film'],
#  ['financement de la vie politique'],
#  ['finances communales'],
#  ['finances départementales'],
#  ['finances locales'],
#  ['finances publiques'],
#  ['finances régionales'],
#  ['fiscalité'],
#  ['fiscalité locale'],
#  ['fleur'],
#  ['fleuve'],
#  ['flore'],
#  ['flottage'],
#  ['foires et marchés'],
#  ["fonctionnement de l'administration"],
#  ['fonctionnement de la justice'],
#  ['fonction publique'],
#  ["fonction publique d'Etat"],
#  ['fonction publique hospitalière'],
#  ['fonction publique territoriale'],
#  ['fond marin'],
#  ['fonds de concours'],
#  ['fonds de la recherche'],
#  ['fonds structurel européen'],
#  ['fontaine'],
#  ['football'],
#  ['forage'],
#  ['force internationale'],
#  ['forces alliées'],
#  ["forces de l'ordre"],
#  ['forêt'],
#  ['forêt communale'],
#  ['forêt domaniale'],
#  ['forêt privée'],
#  ['formation continue'],
#  ['formation en alternance'],
#  ['formation professionnelle'],
#  ['formulaire administratif'],
#  ['fouille archéologique'],
#  ['foyer socio-éducatif'],
#  ['frais de justice'],
#  ['Franc'],
#  ["français de l'étranger"],
#  ['francisme'],
#  ['franc-maçonnerie'],
#  ['francophonie'],
#  ['fraude'],
#  ['fraude électorale'],
#  ['fret'],
#  ['friche industrielle'],
#  ...]

# %% [markdown]
# On récupère ensuite les types documents.

# %%
with open("../../corpus_test/lectaurep/spaCy_bac_a_sable/referentiels/FRAN_RI_001_typesDocuments.tsv", 'r') as file:
    referentiel_mots_matieres = csv.reader(file, delimiter="\t")
    # On récupère la colonne Terme
    types_documents = [i[1:2] for i in referentiel_mots_matieres]
    # On retire le header
    types_documents = types_documents[1:]
    
types_documents
# Out:
# [['accord'],
#  ['accord bilatéral'],
#  ['accord commercial'],
#  ['accord de travail'],
#  ['accord économique'],
#  ['accord international'],
#  ["acte d'état civil"],
#  ['acte de société'],
#  ['acte de vente'],
#  ['acte imparfait'],
#  ['acte notarié'],
#  ['actes de congrès'],
#  ['acte sous seing privé'],
#  ['affiche'],
#  ['agenda'],
#  ['album'],
#  ['annonce légale'],
#  ['annuaire'],
#  ["appel d'offres"],
#  ['armorial'],
#  ['arrêt'],
#  ['arrêté'],
#  ['article de presse'],
#  ['atlas'],
#  ['attestation'],
#  ["autorisation d'exercice professionnel"],
#  ["autorisation d'urbanisme"],
#  ['autorisation de mise sur le marché'],
#  ['avant-projet'],
#  ["avant-projet d'architecture"],
#  ['avant-projet de loi'],
#  ['avis'],
#  ['bail'],
#  ['base de données'],
#  ['bibliographie'],
#  ['bilan'],
#  ['bilan comptable'],
#  ["brevet d'invention"],
#  ['brevet notarié'],
#  ['brochure'],
#  ['budget'],
#  ['bulle pontificale'],
#  ['bulletin de salaire'],
#  ['bulletin de vote'],
#  ["cahier d'enchères"],
#  ['cahier de doléances'],
#  ['cahier des charges'],
#  ['calendrier'],
#  ['caricature'],
#  ['carnet de santé'],
#  ['carte à jouer'],
#  ["carte d'identité"],
#  ["carte d'identité professionnelle"],
#  ['carte de membre'],
#  ['carte de travail'],
#  ['carte de voeu'],
#  ['carte postale'],
#  ["carton d'invitation"],
#  ['cartulaire'],
#  ['catalogue'],
#  ['cautionnement'],
#  ['certificat'],
#  ['cession'],
#  ['chanson'],
#  ['charte'],
#  ['chronique'],
#  ['chrono'],
#  ['circulaire'],
#  ['communiqué'],
#  ['comparution'],
#  ['compte'],
#  ['compte administratif'],
#  ["compte d'exécution testamentaire"],
#  ['compte de gestion'],
#  ['compte de résultat'],
#  ['compte de tutelle'],
#  ['compte financier'],
#  ['compte-rendu'],
#  ['compte-rendu de séance'],
#  ['compte-rendu interministériel'],
#  ['constitution de rente'],
#  ['contrat'],
#  ["contrat d'apprentissage"],
#  ['contrat de mariage'],
#  ['contrat de travail'],
#  ['convention'],
#  ['convention collective'],
#  ['copie (examen et concours)'],
#  ['copie authentique'],
#  ['correspondance'],
#  ['coupure de presse'],
#  ['courrier parlementaire'],
#  ['curriculum vitae'],
#  ['décharge'],
#  ['décision'],
#  ['décision de justice'],
#  ['décision de paiement'],
#  ['déclaration'],
#  ["déclaration d'utilité publique"],
#  ['déclaration féodale'],
#  ['déclaration fiscale'],
#  ['décret'],
#  ['délibération'],
#  ['délivrance de legs'],
#  ["dépôt d'argent"],
#  ['dépôt de pièces'],
#  ['devis'],
#  ['dictionnaire'],
#  ['diplôme'],
#  ['directive européenne'],
#  ['discours'],
#  ['documentation'],
#  ['document cartographique'],
#  ['document graphique'],
#  ['document photographique'],
#  ['document préparatoire'],
#  ['donation'],
#  ["dossier d'agrément"],
#  ["dossier d'homologation"],
#  ['dossier de candidature'],
#  ['dossier de carrière'],
#  ['dossier de client'],
#  ['dossier de consultation des entreprises'],
#  ['dossier de pension'],
#  ['dossier de presse'],
#  ['dossier de procédure judiciaire'],
#  ['dossier de scolarité'],
#  ['dossier de séance'],
#  ['dossier des ouvrages exécutés'],
#  ['dossier de subvention'],
#  ['dossier individuel'],
#  ['dossier médical'],
#  ['dossier technique'],
#  ['échange'],
#  ['écrit du for privé'],
#  ['édit'],
#  ['enquête'],
#  ["enquête d'opinion"],
#  ['étude'],
#  ["extrait d'acte"],
#  ['faire-part'],
#  ['fiche'],
#  ['fiche nominative'],
#  ['fichier'],
#  ['fondation'],
#  ['fondation pieuse'],
#  ['formulaire administratif'],
#  ['indemnité'],
#  ['inventaire'],
#  ['inventaire après décès'],
#  ['laissez-passer'],
#  ['lettre de change'],
#  ['lettre de mission'],
#  ['liquidation'],
#  ['liste'],
#  ['liste électorale'],
#  ['liste nominative'],
#  ['livre comptable'],
#  ["livre d'or"],
#  ['livre liturgique'],
#  ['livret militaire'],
#  ['livret ouvrier'],
#  ['loi'],
#  ['main courante'],
#  ['mainlevée'],
#  ['maquette'],
#  ['marché'],
#  ['marché public'],
#  ['marque de fabrique'],
#  ['médaille'],
#  ['menu'],
#  ['mercuriale'],
#  ['minute notariale'],
#  ['modèle de fabrique'],
#  ['motion'],
#  ['motion parlementaire'],
#  ['nécrologie'],
#  ['nomination'],
#  ['norme'],
#  ['note'],
#  ['note de renseignement'],
#  ['note de service'],
#  ['notoriété'],
#  ['objet'],
#  ['obligation'],
#  ['ordonnance'],
#  ['ordre de mission'],
#  ['organigramme'],
#  ['ouvrage imprimé'],
#  ["panneau d'exposition"],
#  ['partage'],
#  ['partition musicale'],
#  ['passeport'],
#  ['permis'],
#  ['permis de recherche'],
#  ['pétition'],
#  ['pièce comptable'],
#  ['placard'],
#  ['plan'],
#  ['plan cadastral'],
#  ["plan d'architecture"],
#  ["plan d'urbanisme"],
#  ["plan local d'urbanisme"],
#  ['plan terrier'],
#  ['procès-verbal'],
#  ["procès-verbal d'élection"],
#  ['procès-verbal de séance'],
#  ['procuration'],
#  ['profession de foi'],
#  ['programme'],
#  ['projet de loi'],
#  ['promesse'],
#  ['proposition de loi'],
#  ['protêt'],
#  ['publication officielle'],
#  ['publication périodique'],
#  ['questionnaire'],
#  ["questionnaire d'enquête"],
#  ['question parlementaire'],
#  ['quittance'],
#  ['rapport'],
#  ["rapport d'activité"],
#  ["rapport d'expertise"],
#  ["rapport d'inspection"],
#  ['rapport de mission'],
#  ["rapport des forces de l'ordre"],
#  ['rapport de stage'],
#  ['ratification'],
#  ['reconnaissance'],
#  ['registre'],
#  ["registre d'audience"],
#  ['registre de catholicité'],
#  ['registre paroissial'],
#  ['registre protestant'],
#  ['règlement'],
#  ['relevé météorologique'],
#  ["remboursement d'office"],
#  ['renonciation'],
#  ['répertoire'],
#  ["répertoire d'officier public ministériel"],
#  ['revue de presse'],
#  ["rôle d'équipage"],
#  ['sceau'],
#  ['schéma directeur'],
#  ['statistique'],
#  ['statuts'],
#  ["statuts d'association"],
#  ['substitution'],
#  ['sujet (examen et concours)'],
#  ['tarif'],
#  ['télégramme'],
#  ['télégramme diplomatique'],
#  ['terrier'],
#  ['testament'],
#  ['thèse'],
#  ['timbre postal'],
#  ['titre de propriété'],
#  ['titre de séjour'],
#  ['titre nouvel'],
#  ['tract'],
#  ['traité'],
#  ["traité d'office"],
#  ['transport de droits']]

# %% [markdown]
# On importe le matcher spacy.

# %%
from spacy.matcher import PhraseMatcher
from spacy.matcher import Matcher
from spacy.tokens import Span

# %% [markdown]
# On instancie l'objet PhraseMatcher avec l'objet vocab. Ce dernier stocke le vocabulaire d'un modèle chargé.

# %%
matcher_types_documents = PhraseMatcher(nlp.vocab)

# %% [markdown]
# ## Création du matcher pour les types documents

# %%
# On fait passer tous les mots récupérés par la pipeline nlp() et on stocke la liste
phrase_patterns_types_documents = [nlp(text) for i in types_documents for text in i]

# On applique les patterns au matcher object
matcher_types_documents.add('typesdocuments', None, *phrase_patterns_types_documents)

# %% [markdown]
# On récupère les potentiels matches.

# %%
matches_types_documents = matcher_types_documents(doc_2)

matches_types_documents
# match_id, start, end
# Out:
# [(11869306371800119346, 473, 474), (11869306371800119346, 1009, 1010)]

# %% [markdown]
# On affiche les matches récupérés.

# %%
for match_id, start, end in matches_types_documents:
    span = Span(doc_2, start, end, label=match_id)
    print(span.text, span.label_)
# Out:
# procuration typesdocuments
# donation typesdocuments

# %% [markdown]
# ## Création du matcher pour les mots matières

# %%
matcher_mots_matieres = PhraseMatcher(nlp.vocab)

# %%
phrase_patterns_mots_matieres = [nlp(text) for i in mots_matieres for text in i]

# On applique les patterns au matcher object
matcher_mots_matieres.add('motsmatieres', None, *phrase_patterns_mots_matieres)

# %%
matches_mots_matieres = matcher_mots_matieres(doc_2)

matches_mots_matieres
# Out:
# [(2578879220600662430, 121, 122),
#  (2578879220600662430, 169, 170),
#  (2578879220600662430, 204, 205),
#  (2578879220600662430, 286, 287),
#  (2578879220600662430, 375, 376),
#  (2578879220600662430, 495, 496),
#  (2578879220600662430, 503, 504),
#  (2578879220600662430, 816, 817),
#  (2578879220600662430, 885, 886),
#  (2578879220600662430, 915, 916)]

# %%
for match_id, start, end in matches_mots_matieres:
    span = Span(doc_2, start, end, label=match_id)
    print(span.text, span.label_)
# Out:
# adjudication motsmatieres
# prêt motsmatieres
# succession motsmatieres
# or motsmatieres
# décès motsmatieres
# boulevard motsmatieres
# droit motsmatieres
# mariage motsmatieres
# change motsmatieres
# publication motsmatieres

# %% [markdown]
# **Danger : le référentiel entraîne l'identification de boulevard comme mot matière et non comme 'LOC'**

# %% [markdown]
# ## On recommence la procédure en excluant les matches_mots_matieres

# %%
matches_types_documents = matcher_types_documents(doc_2)

for match_id, start, end in matches_types_documents:
    span = Span(doc_2, start, end, label=match_id)
    print(span.text, span.label_)
# Out:
# procuration typesdocuments
# donation typesdocuments

# %% [markdown]
# On crée des entités nommées pour les matches types documents.

# %%
# On se calque sur la liste des tags d'entités nommées, on utilise LAW
LAW = doc_2.vocab.strings[u'LAW']

# On crée les nouvelles entités en utilisant la position des tokens et en utilisant le label qu'on a créé
new_ents = [Span(doc_2, match[1], match[2], label=LAW) for match in matches_types_documents]

# On ajoute les nouvelles entités aux entités trouvées par défaut
doc_2.ents = list(doc_2.ents) + new_ents

# %%
for entity in doc_2.ents:
    print(f'{entity.text}: {entity.label_}')
# Out:
# An 1908: MISC
# Mai: LOC
# Louise Amable Anaïs: PER
# 45 Boulevard: LOC
# Certificatdevie Barry: MISC
# Jenny Antoinette Hélène: PER
# Ternes: LOC
# Barry: PER
# Jeanne Marie Pierrette Suzanne: PER
# Barry: PER
# Jeanne Madeleine Anaïs Hélène: PER
# Goyon: PER
# Marie Joseph Verteuil François Xavier: PER
# Londres: LOC
# Angleterre: LOC
# X XX Street: LOC
# Wilmès: PER
# Emile Léon: PER
# Epinay Procès-verbal d'adjudication 7: MISC
# Seine: LOC
# Marcel: PER
# Santeuil: PER
# Berthe Pinson: PER
# Réalisation de prêt Delamaire: MISC
# Créditfoncier: LOC
# Mr: PER
# Made: PER
# Etat: LOC
# Charmet: ORG
# Paul Louis: PER
# Lucie 8 Noëla Sylvestre: MISC
# M. Charmet: PER
# Pr: PER
# Verb: ORG
# Charmet: LOC
# Jeanne Van de Weyer: PER
# Ecoles: LOC
# Baptiste Van: PER
# Aléide Leroy: PER
# Paris: LOC
# Neuilly s/ Marne: LOC
# Notoriété Faivre: PER
# Auguste Robert: PER
# rue des Roses: LOC
# Dijon: LOC
# Côte d'or: LOC
# Bail Février: MISC
# Barbe Bir: LOC
# Chamos Elysées: LOC
# Perreux 488: LOC
# Seine: LOC
# Alfred: PER
# Louis Honoré Prudhomme: PER
# Juliette Augustine Gruchon: PER
# Bd de Belleville: LOC
# Bd de Belleville: LOC
# 489 Prévost: LOC
# Communauté: LOC
# Caroline Henriette Liquidation: PER
# Kohler: PER
# Victor Michel: PER
# Succession: MISC
# Inventaire Maron: MISC
# Victoire Prudence: PER
# Jacques: PER
# Belleville: LOC
# Jean Pierre: PER
# Noisy: LOC
# Quittance Dubois: PER
# Maria Bonnial: PER
# Jeanà 25: ORG
# Envierges: MISC
# Samuel Lévy: PER
# Lunéville: LOC
# Alphonse Mayse: PER
# Baccarat: LOC
# Substitution depouvoirs Dhoutaut: MISC
# Durin: PER
# Mme Veuve Marchand: PER
# Substitution de pouvoirs: MISC
# Dhoutant: MISC
# Durin: PER
# procuration: LAW
# Septembre 1907 Pavy: MISC
# Constant Marie Alfred: PER
# Paris boulevard St Michel 87: LOC
# Ambroise Confirmation: PER
# Edouard Doncède: PER
# Paris: LOC
# Assomption: MISC
# Prosper Biles: PER
# Limoges: LOC
# Jean Pénicaud: PER
# Procuration Bauer: MISC
# Georges: MISC
# Julie Féron: PER
# rue Berger: LOC
# Notoriété Leblanc: PER
# Eugène Jean: PER
# Temple: LOC
# Marie Sophie Cécile Ségnier 4avenue: PER
# Louis 11 Charles Henri de Ranst: PER
# Berchern Comte: PER
# Durin: PER
# Procuration Artus: PER
# Louise Auguste Rennes: PER
# Gustave: PER
# Hennedouche: LOC
# Comptoir: ORG
# Martin: PER
# Alexandre: PER
# rue Lehain: LOC
# Asnières: LOC
# Pierre Martin: PER
# Craon: LOC
# Vienne: LOC
# Dépôt de lagrosse Gallois: MISC
# Louis Philippe: PER
# rue Ducange: LOC
# Possession: MISC
# Vigouroux: PER
# Crédit foncier de France: ORG
# Profit: MISC
# Pierre: MISC
# Rose Juény: PER
# Paris: LOC
# Procuration 14: MISC
# Bordat: PER
# Hélène Marie: PER
# Bugeaud: PER
# Procuration 14: MISC
# Eugène: PER
# 84 Bd de Ménilmontant: LOC
# 14 Compte: MISC
# Delarue: MISC
# S: LOC
# Elie: MISC
# Assas: LOC
# Marie Grosse: PER
# Noel: PER
# Paris: LOC
# Blancs: LOC
# Veuve Fitanza: LOC
# Jacques: PER
# Léon Gabriel: PER
# Paris: LOC
# Emilie Léonie Seillier: PER
# Paris: LOC
# Victor Massé 14: PER
# Emile Denis Poplin: PER
# Procuration Defond: PER
# Louis Lucien: PER
# Marie Justine Pauline Rezard de Wouves: PER
# Franceville: LOC
# Gagny: LOC
# Seine: LOC
# Oise: LOC
# Charles Eugène: PER
# Francaise: LOC
# Société anonyme: ORG
# Paris: LOC
# Laffitte: LOC
# Décharge: MISC
# Bordinat: MISC
# Désiré Arsène: PER
# Paris: LOC
# Marcel Pierre Jules Laforge: PER
# Aix: LOC
# Angillon: LOC
# Cher: LOC
# Notoriété: ORG
# Aymonet de Contréglise: PER
# Athénaïs: PER
# Alexandrine Joséphine: PER
# Guingamp: LOC
# Côtes du Nord: LOC
# Loubens de Verdalle: PER
# Abel: PER
# Paris ave du Maine: LOC
# Denis Procuration: PER
# Yzeures: LOC
# Allier: LOC
# donation: LAW

# %% [markdown]
# # Modification des règles pour segmentation des phrases

# %% [markdown]
# Précédemment, nous avons remarqué que la segmentation ne pouvait pas être proprement réalisée à cause de la nature des documents.
#
# SpaCy propose deux façons de segmenter les phrases d'un texte :
# * Une segmentation statistique, réalisée dans la pipeline spaCy par le **parser**, qui traite les dépendances.
# * Une segmentation des phrases à l'aide de règles.
#
# Nous explorerons cette deuxième solution pour cette expérimentation.

# %%
nlp_sentence_segmentation_new_rule = spacy.load("fr_core_news_lg")

# %% [markdown]
# On importe le même document utilisé au début de ce notebook, mais cette fois on utilise une version manuellement annotée après récupération de la transcription manuelle.
#
# On a ainsi rajouté des **;** à chaque fin d'unité sémantique, correspondant donc à une entrée faite par un.e notaire. Nous nous baserons donc sur les points-virgules pour segmenter le texte et voir si cela a un impact sur le NER.
#
# Le choix du point-virgule est pour le moment temporaire. Celui-ci n'est en effet pas robuste, les notaires utilisant ce symbole de ponctuation.

# %%
with open('../../corpus_test/lectaurep/doc_28_sample/manual_transcription/artificial_sentence_segmentation/text_with_artificial_separation.txt', 'r', encoding='UTF-8') as file:
    sample_artificial_separation = file.read()

# %% [markdown]
# On ajoute à la pipeline le sentencizer.

# %%
# On crée une variable config qui va stocker la configuration du sentencizer.
# La variable prend la forme d'un dictionnaire, contenant une clé punt_chars et un dictionnaire en valeur.
config = {"punct_chars": [";"]}

# On ajoute le sentencizer dans la pipeline, avec la config, et on s'assure qu'on fait exécuter cette tâche avant le parser.
nlp_sentence_segmentation_new_rule.add_pipe("sentencizer", config=config, before="parser")

# %%
nlp_sentence_segmentation_new_rule.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f39162279f0>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x7f39161bbae0>),
#  ('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x7f391628d640>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f3916298fa0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f391628ae20>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f39161a5640>),
#  ('lemmatizer', <spacy.lang.fr.lemmatizer.FrenchLemmatizer at 0x7f39161a80c0>)]

# %%
doc_3 = nlp_sentence_segmentation_new_rule(sample_artificial_separation)

# %%
for sent in doc_3.sents:
    print(sent)
    print("\n")
# Out:
# An 1901 , mois de Février ;
#
#
#
# Dupuis, (par Pierre) à Paris, rue Turgot 4, à Catherine Bizial, sa femme ;
#
#
#
# - d° - (par Mme) s. n. à son mari ;
#
#
#
# Murel (par Paul Louis Georges) dt à Paris, Bd Rochechouart 68, et Marie Joséphine
# Lemaire, dt à Paris, même adresse (Séparation de biens) ;
#
#
#
# Dubosc (ct titre de 380+ de rente 3% au nom  de : Debuisson, Justine Adèle,
# Vve de Jules) et autres, à Paris, rue de l’Arcade 20 ;
#
#
#
# Rouy (par Edmond Narcisse), dt à Paris, rue Cavalotti 15, et autres, pr toucher &amp;
#
#
# recevoir ;
#
#
#
# Chabrol (par Marie Louise Vatonne, Ve de Marie Eusèbe Maxime) dt à Billancourt, route de
# Versailles, 128, à Eugène Vatrin et Marceline Freling, dt à Billancourt, rue Nationale 31, de 21 303,88 ;
#
#
#
# Gauthier (par Marie Alexandrine) à Paris, rue St Ferdinand 2, à ses père et mère ;
#
#
#
# Cusson (par Georges Ernest Léon) dt à Paris, rue Lamarck 144, à son père ;
#
#
#
# Lecrosnier (ct livret de caisse d’Epargne de Paris, de 157,19 au nom de Pierre
# Auguste) décédé en son domicile à Paris, rue Descartes 21, le 16 8bre 1900 ;
#
#
#
# Lettéron (ct les prénoms de Louis Emile) décédé en son dom. à Villeneuve-St Georges, le 15 7bre 1897 ;
#
#
#
# Dupont (par Léonie Albertine Octavie) rue St-Lazare 82, à Honoré Bouscarat et sa
# femme, à Montelaux (Aveyron) et à Achille Dareau, rue Guyot 17 de boutique aud. lieu ;
#
#
#
# de Lecanta y Mendieta (ct Joaquina Dolores Conception de Orbeta y
# Alguirre Ve Manuel), décédée à Bilbat, 23 calle de Btodebarriéta le 25 Mai 1900 ;
#
#
#
# Théoule (par Alfred Sylvain Georges) dt à Paris, rue Bracq, 4, à sa mère ;
#
#
#
# de Neufville (par Jacob Guillaume) dt à Paris, rue Halévy 6, de valeurs dotales appt à Mme de Boissieux;
#
#
#
# de Morangiès (de Marie Gertrude Oboril, épouse de Clodomir Albert) dt à
# Paris, rue du Printemps, 22 ;
#
#
#
# - d° - (dud. état) ;
#
#
#
# Sté Block frères et Cie (par la Sté) siège à Toul, à Gabriel Henri Coujat,
# rue du Printemps 7, de 7.875+ ;
#
#
#
# Henry (par Augustine Victoire Lecharpentier, épouse de Jean-Baptiste) à Paris,
# rue d’Athènes, 24, au mariage de sa fille ;
#
#
#
# Moreau Simond (par Gustave Arthur Félix) et Marie Françoise Pellerin;
#
#
#
# Epx à Paris rue des Batignolles 76, pr vendre immeuble ;
#
#
#
# Harant (par Marthe Caroline Duval, rue Pigalle 11b, Ve de Alexandre Victor Armand)
# à Joseph Eugène Bogel et Marie Adelphine Julien, à Asnières, rue de Châteaudun 22, pr 10000+ px de vente ;
#
#
#
# Prat (ct livret de caisse des retraites pour la vieillesse , 150 + au nom de Jean
# Joseph) décédé en son dom. à Paris, rue de l’Annonciation 28, le 23 8bre 1900 ;
#
#
#
# Boudon (de Pauline Antoinette Meyer, veen 1eres noces de Alexandre Chatel et en 2es
# noces de François) décédé en son dom. à Paris, rue de Courcelles 192, le 21 février 1901 ;
#
#
#
# de Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à Juan Mariano
# Cte de Guagui, Mis de Villafuerte, même adresse, pr acq. de la Sté des Coteaux de Longchamps ;
#
#
#
# Sté des locomotives sans foyer (ct la) par Léon Francq, à Paris
# 48 avenue Victor Hugo ;
#
#
#
# Lebedel (de Albéric Jean-Baptiste) à Paris, avenue Victoria 17, et Lucie Augustine
# Henry, à Paris rue d’Athènes 24 (communauté réduites aux acquêts) ;
#
#
#
# de Goyenèche (par Juan Mariano de Goyenèche y Gannio comte de Guagui,
# dt à Paris avenue de Friedland 15, et autres ;
#
#
#
# de Goyenèche (par Carmen) dt à Paris avenue de Friedland 15, à la Sté Fse des Coteaux du
# Bois de Boulogne et de Longchamps, siège à Paris rue de l’Isly 9,  de 3 parcelles de terrain moyt 189585+ ;
#
#
#
# Guille Stevens Le Marchant (ct titre de 396+ de rente 3% au nom de) Henri, dt à
# Grumbanck Croconhill Plymouth Conté de Devon (Angleterre) décédé le 9 mai 1900 à Sadysmith ;
#
#
#
# Knaier (par Françoise Rouchard, épouse de Alphonse), rue Laferrière 17, pr retirer
# toutes sommes de la Caisse d’Epargne postale ;
#
#
#
# Dutrey (par Marguerite Elvire Herneis, épouse de Jean Victor) dt à Paris, rue
# Legendre 176, pr recueillir SSon ;
#
#
#
# Manot (par Engrace Millacet, épouse de Pierre) dt à Paris, rue de Grenelle,
# 55, à M. Pillard, clerc ;
#
#
#
# Fournié (après décès de Marie Muller, Ve de Marcelin) décédée en son domicile à
# Paris, rue Beuret 20, le 11 février 1901 ;
#
#
#
# Teil (par le Crédit foncier à François) dt à Bois Colombes, villa Schutz, 13, de 22.000+ ;

# %%
for sent in doc_3.sents:
    print([token.text for token in sent])
# Out:
# ['An', '1901', ',', 'mois', 'de', 'Février', ';']
# ['\n', 'Dupuis', ',', '(', 'par', 'Pierre', ')', 'à', 'Paris', ',', 'rue', 'Turgot', '4', ',', 'à', 'Catherine', 'Bizial', ',', 'sa', 'femme', ';']
# ['\n', '-', 'd°', '-', '(', 'par', 'Mme', ')', 's.', 'n.', 'à', 'son', 'mari', ';']
# ['\n', 'Murel', '(', 'par', 'Paul', 'Louis', 'Georges', ')', 'dt', 'à', 'Paris', ',', 'Bd', 'Rochechouart', '68', ',', 'et', 'Marie', 'Joséphine', '\n', 'Lemaire', ',', 'dt', 'à', 'Paris', ',', 'même', 'adresse', '(', 'Séparation', 'de', 'biens', ')', ';']
# ['\n', 'Dubosc', '(', 'ct', 'titre', 'de', '380', '+', 'de', 'rente', '3', '%', 'au', 'nom', ' ', 'de', ':', 'Debuisson', ',', 'Justine', 'Adèle', ',', '\n', 'Vve', 'de', 'Jules', ')', 'et', 'autres', ',', 'à', 'Paris', ',', 'rue', 'de', 'l’', 'Arcade', '20', ';']
# ['\n', 'Rouy', '(', 'par', 'Edmond', 'Narcisse', ')', ',', 'dt', 'à', 'Paris', ',', 'rue', 'Cavalotti', '15', ',', 'et', 'autres', ',', 'pr', 'toucher', '&', 'amp', ';']
# ['recevoir', ';']
# ['\n', 'Chabrol', '(', 'par', 'Marie', 'Louise', 'Vatonne', ',', 'Ve', 'de', 'Marie', 'Eusèbe', 'Maxime', ')', 'dt', 'à', 'Billancourt', ',', 'route', 'de', '\n', 'Versailles', ',', '128', ',', 'à', 'Eugène', 'Vatrin', 'et', 'Marceline', 'Freling', ',', 'dt', 'à', 'Billancourt', ',', 'rue', 'Nationale', '31', ',', 'de', '21', '303,88', ';']
# ['\n', 'Gauthier', '(', 'par', 'Marie', 'Alexandrine', ')', 'à', 'Paris', ',', 'rue', 'St', 'Ferdinand', '2', ',', 'à', 'ses', 'père', 'et', 'mère', ';']
# ['\n', 'Cusson', '(', 'par', 'Georges', 'Ernest', 'Léon', ')', 'dt', 'à', 'Paris', ',', 'rue', 'Lamarck', '144', ',', 'à', 'son', 'père', ';']
# ['\n', 'Lecrosnier', '(', 'ct', 'livret', 'de', 'caisse', 'd’', 'Epargne', 'de', 'Paris', ',', 'de', '157,19', 'au', 'nom', 'de', 'Pierre', '\n', 'Auguste', ')', 'décédé', 'en', 'son', 'domicile', 'à', 'Paris', ',', 'rue', 'Descartes', '21', ',', 'le', '16', '8bre', '1900', ';']
# ['\n', 'Lettéron', '(', 'ct', 'les', 'prénoms', 'de', 'Louis', 'Emile', ')', 'décédé', 'en', 'son', 'dom', '.', 'à', 'Villeneuve-St', 'Georges', ',', 'le', '15', '7bre', '1897', ';']
# ['\n', 'Dupont', '(', 'par', 'Léonie', 'Albertine', 'Octavie', ')', 'rue', 'St', '-', 'Lazare', '82', ',', 'à', 'Honoré', 'Bouscarat', 'et', 'sa', '\n', 'femme', ',', 'à', 'Montelaux', '(', 'Aveyron', ')', 'et', 'à', 'Achille', 'Dareau', ',', 'rue', 'Guyot', '17', 'de', 'boutique', 'aud', '.', 'lieu', ';']
# ['\n', 'de', 'Lecanta', 'y', 'Mendieta', '(', 'ct', 'Joaquina', 'Dolores', 'Conception', 'de', 'Orbeta', 'y', '\n', 'Alguirre', 'Ve', 'Manuel', ')', ',', 'décédée', 'à', 'Bilbat', ',', '23', 'calle', 'de', 'Btodebarriéta', 'le', '25', 'Mai', '1900', ';']
# ['\n', 'Théoule', '(', 'par', 'Alfred', 'Sylvain', 'Georges', ')', 'dt', 'à', 'Paris', ',', 'rue', 'Bracq', ',', '4', ',', 'à', 'sa', 'mère', ';']
# ['\n', 'de', 'Neufville', '(', 'par', 'Jacob', 'Guillaume', ')', 'dt', 'à', 'Paris', ',', 'rue', 'Halévy', '6', ',', 'de', 'valeurs', 'dotales', 'appt', 'à', 'Mme', 'de', 'Boissieux', ';']
# ['\n', 'de', 'Morangiès', '(', 'de', 'Marie', 'Gertrude', 'Oboril', ',', 'épouse', 'de', 'Clodomir', 'Albert', ')', 'dt', 'à', '\n', 'Paris', ',', 'rue', 'du', 'Printemps', ',', '22', ';']
# ['\n', '-', 'd°', '-', '(', 'dud', '.', 'état', ')', ';']
# ['\n', 'Sté', 'Block', 'frères', 'et', 'Cie', '(', 'par', 'la', 'Sté', ')', 'siège', 'à', 'Toul', ',', 'à', 'Gabriel', 'Henri', 'Coujat', ',', '\n', 'rue', 'du', 'Printemps', '7', ',', 'de', '7.875', '+', ';']
# ['\n', 'Henry', '(', 'par', 'Augustine', 'Victoire', 'Lecharpentier', ',', 'épouse', 'de', 'Jean-Baptiste', ')', 'à', 'Paris', ',', '\n', 'rue', 'd’', 'Athènes', ',', '24', ',', 'au', 'mariage', 'de', 'sa', 'fille', ';']
# ['\n', 'Moreau', 'Simond', '(', 'par', 'Gustave', 'Arthur', 'Félix', ')', 'et', 'Marie', 'Françoise', 'Pellerin', ';']
# ['\n', 'Epx', 'à', 'Paris', 'rue', 'des', 'Batignolles', '76', ',', 'pr', 'vendre', 'immeuble', ';']
# ['\n', 'Harant', '(', 'par', 'Marthe', 'Caroline', 'Duval', ',', 'rue', 'Pigalle', '11b', ',', 'Ve', 'de', 'Alexandre', 'Victor', 'Armand', ')', '\n', 'à', 'Joseph', 'Eugène', 'Bogel', 'et', 'Marie', 'Adelphine', 'Julien', ',', 'à', 'Asnières', ',', 'rue', 'de', 'Châteaudun', '22', ',', 'pr', '10000', '+', 'px', 'de', 'vente', ';']
# ['\n', 'Prat', '(', 'ct', 'livret', 'de', 'caisse', 'des', 'retraites', 'pour', 'la', 'vieillesse', ',', '150', '+', 'au', 'nom', 'de', 'Jean', '\n', 'Joseph', ')', 'décédé', 'en', 'son', 'dom', '.', 'à', 'Paris', ',', 'rue', 'de', 'l’', 'Annonciation', '28', ',', 'le', '23', '8bre', '1900', ';']
# ['\n', 'Boudon', '(', 'de', 'Pauline', 'Antoinette', 'Meyer', ',', 'veen', '1eres', 'noces', 'de', 'Alexandre', 'Chatel', 'et', 'en', '2es', '\n', 'noces', 'de', 'François', ')', 'décédé', 'en', 'son', 'dom', '.', 'à', 'Paris', ',', 'rue', 'de', 'Courcelles', '192', ',', 'le', '21', 'février', '1901', ';']
# ['\n', 'de', 'Goyenèche', '(', 'par', 'Carmen', ')', 'dt', 'à', 'Paris', 'avenue', 'de', 'Friedland', '15', ',', 'à', 'Juan', 'Mariano', '\n', 'Cte', 'de', 'Guagui', ',', 'Mis', 'de', 'Villafuerte', ',', 'même', 'adresse', ',', 'pr', 'acq', '.', 'de', 'la', 'Sté', 'des', 'Coteaux', 'de', 'Longchamps', ';']
# ['\n', 'Sté', 'des', 'locomotives', 'sans', 'foyer', '(', 'ct', 'la', ')', 'par', 'Léon', 'Francq', ',', 'à', 'Paris', '\n', '48', 'avenue', 'Victor', 'Hugo', ';']
# ['\n', 'Lebedel', '(', 'de', 'Albéric', 'Jean-Baptiste', ')', 'à', 'Paris', ',', 'avenue', 'Victoria', '17', ',', 'et', 'Lucie', 'Augustine', '\n', 'Henry', ',', 'à', 'Paris', 'rue', 'd’', 'Athènes', '24', '(', 'communauté', 'réduites', 'aux', 'acquêts', ')', ';']
# ['\n', 'de', 'Goyenèche', '(', 'par', 'Juan', 'Mariano', 'de', 'Goyenèche', 'y', 'Gannio', 'comte', 'de', 'Guagui', ',', '\n', 'dt', 'à', 'Paris', 'avenue', 'de', 'Friedland', '15', ',', 'et', 'autres', ';']
# ['\n', 'de', 'Goyenèche', '(', 'par', 'Carmen', ')', 'dt', 'à', 'Paris', 'avenue', 'de', 'Friedland', '15', ',', 'à', 'la', 'Sté', 'Fse', 'des', 'Coteaux', 'du', '\n', 'Bois', 'de', 'Boulogne', 'et', 'de', 'Longchamps', ',', 'siège', 'à', 'Paris', 'rue', 'de', 'l’', 'Isly', '9', ',', ' ', 'de', '3', 'parcelles', 'de', 'terrain', 'moyt', '189585', '+', ';']
# ['\n', 'Guille', 'Stevens', 'Le', 'Marchant', '(', 'ct', 'titre', 'de', '396', '+', 'de', 'rente', '3', '%', 'au', 'nom', 'de', ')', 'Henri', ',', 'dt', 'à', '\n', 'Grumbanck', 'Croconhill', 'Plymouth', 'Conté', 'de', 'Devon', '(', 'Angleterre', ')', 'décédé', 'le', '9', 'mai', '1900', 'à', 'Sadysmith', ';']
# ['\n', 'Knaier', '(', 'par', 'Françoise', 'Rouchard', ',', 'épouse', 'de', 'Alphonse', ')', ',', 'rue', 'Laferrière', '17', ',', 'pr', 'retirer', '\n', 'toutes', 'sommes', 'de', 'la', 'Caisse', 'd’', 'Epargne', 'postale', ';']
# ['\n', 'Dutrey', '(', 'par', 'Marguerite', 'Elvire', 'Herneis', ',', 'épouse', 'de', 'Jean', 'Victor', ')', 'dt', 'à', 'Paris', ',', 'rue', '\n', 'Legendre', '176', ',', 'pr', 'recueillir', 'SSon', ';']
# ['\n', 'Manot', '(', 'par', 'Engrace', 'Millacet', ',', 'épouse', 'de', 'Pierre', ')', 'dt', 'à', 'Paris', ',', 'rue', 'de', 'Grenelle', ',', '\n', '55', ',', 'à', 'M.', 'Pillard', ',', 'clerc', ';']
# ['\n', 'Fournié', '(', 'après', 'décès', 'de', 'Marie', 'Muller', ',', 'Ve', 'de', 'Marcelin', ')', 'décédée', 'en', 'son', 'domicile', 'à', '\n', 'Paris', ',', 'rue', 'Beuret', '20', ',', 'le', '11', 'février', '1901', ';']
# ['\n', 'Teil', '(', 'par', 'le', 'Crédit', 'foncier', 'à', 'François', ')', 'dt', 'à', 'Bois', 'Colombes', ',', 'villa', 'Schutz', ',', '13', ',', 'de', '22.000', '+', ';']
# ['\n']

# %%
for entity in doc_3.ents:
    print(f'{entity.text}: {entity.label_}')
# Out:
# An 1901: MISC
# Dupuis: ORG
# Pierre: MISC
# Paris: LOC
# rue Turgot: LOC
# Catherine Bizial: PER
# Mme: PER
# Murel: MISC
# Paul Louis Georges: PER
# Paris: LOC
# Bd Rochechouart: LOC
# Marie Joséphine
# Lemaire: PER
# Paris: LOC
# Séparation: MISC
# Dubosc: PER
# Debuisson: PER
# Justine Adèle: PER
# Vve de Jules: PER
# Paris: LOC
# rue de l’Arcade 20: LOC
# Rouy: LOC
# Edmond Narcisse: PER
# Paris: LOC
# Cavalotti 15: MISC
# Chabrol: PER
# Marie Louise Vatonne: PER
# Ve: LOC
# Marie Eusèbe Maxime: PER
# Billancourt: LOC
# Versailles: LOC
# Eugène Vatrin: PER
# Marceline Freling: PER
# Billancourt: LOC
# rue Nationale 31: LOC
# Gauthier: PER
# Marie Alexandrine: PER
# Paris: LOC
# rue St Ferdinand 2: LOC
# Cusson: PER
# Georges Ernest Léon: PER
# Paris: LOC
# Lamarck: PER
# Lecrosnier: PER
# Epargne de Paris: MISC
# Pierre
# Auguste: PER
# Paris: LOC
# rue Descartes: LOC
# Louis Emile: PER
# Villeneuve-St Georges: MISC
# Dupont: PER
# Léonie Albertine Octavie: PER
# rue St: LOC
# Lazare: LOC
# Honoré Bouscarat: PER
# Montelaux: LOC
# Aveyron: LOC
# Achille Dareau: PER
# Guyot: PER
# Lecanta y Mendieta: PER
# Joaquina Dolores Conception de Orbeta: MISC
# Alguirre Ve Manuel: MISC
# Bilbat: LOC
# calle de Btodebarriéta: LOC
# Théoule: LOC
# Alfred Sylvain Georges: PER
# Paris: LOC
# rue Bracq: LOC
# Neufville: PER
# Jacob Guillaume: PER
# Paris: LOC
# Halévy: PER
# Mme de Boissieux: PER
# Morangiès: LOC
# Marie Gertrude Oboril: PER
# Clodomir Albert: PER
# Paris: LOC
# rue du Printemps: LOC
# Sté Block frères: MISC
# Cie: MISC
# Sté: ORG
# Toul: LOC
# Gabriel Henri Coujat: PER
# Printemps 7: MISC
# Henry: PER
# Augustine Victoire Lecharpentier: PER
# Jean-Baptiste: PER
# Paris: LOC
# Athènes: LOC
# Moreau Simond: PER
# Gustave Arthur Félix: PER
# Marie Françoise Pellerin: PER
# Epx: LOC
# Paris: LOC
# Harant: PER
# Marthe Caroline Duval: PER
# rue Pigalle 11b: LOC
# Ve: LOC
# Alexandre Victor Armand: PER
# Joseph Eugène Bogel: PER
# Marie Adelphine Julien: PER
# Asnières: LOC
# Châteaudun: LOC
# Prat: PER
# Jean
# Joseph: PER
# Paris: LOC
# rue de l’: LOC
# Annonciation 28: MISC
# Boudon: PER
# Pauline Antoinette Meyer: PER
# Alexandre Chatel: PER
# François: PER
# Paris: LOC
# Courcelles: LOC
# Goyenèche: LOC
# Carmen: PER
# Paris: LOC
# Juan Mariano
# Cte de Guagui: PER
# Villafuerte: PER
# Sté des Coteaux de Longchamps: ORG
# Sté: ORG
# Léon Francq: PER
# Paris: LOC
# Victor Hugo: PER
# Albéric Jean-Baptiste: PER
# Paris: LOC
# Lucie Augustine
# Henry: PER
# Paris: LOC
# Athènes 24: LOC
# Goyenèche: LOC
# Juan Mariano de Goyenèche: PER
# Gannio: LOC
# Paris: LOC
# Goyenèche: LOC
# Carmen: PER
# Paris: LOC
# Sté Fse des Coteaux du
# Bois de Boulogne: ORG
# Longchamps: LOC
# Paris: LOC
# rue de l’Isly 9: LOC
# Guille Stevens Le Marchant: PER
# Henri: PER
# Grumbanck Croconhill Plymouth Conté de Devon: MISC
# Angleterre: LOC
# Sadysmith: LOC
# Knaier: LOC
# Françoise Rouchard: PER
# Alphonse: PER
# Caisse d’Epargne postale: ORG
# Dutrey: PER
# Marguerite Elvire Herneis: PER
# Jean Victor: PER
# Paris: LOC
# rue
# Legendre: LOC
# SSon: LOC
# Manot: LOC
# Engrace Millacet: PER
# Pierre: MISC
# Paris: LOC
# rue de Grenelle: LOC
# M. Pillard: PER
# Fournié: PER
# Marie Muller: PER
# Ve de Marcelin: PER
# Paris: LOC
# rue Beuret 20: LOC
# Teil: LOC
# Crédit foncier: ORG
# François: PER
# Bois Colombes: LOC
# Schutz: PER

# %%
len(doc_3.ents)
# Out:
# 170

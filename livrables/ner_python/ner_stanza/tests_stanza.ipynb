# %% [markdown]
# # Tests avec Stanza
# Voir la documentation : https://stanfordnlp.github.io/stanza/

# %%
import re

from bs4 import BeautifulSoup
import stanza

# %% [markdown]
# ## Installation de la pipeline

# %% [markdown]
# Il est nécessaire d'installer la chaîne de traitement en langue française pour traiter du texte avec Stanza.

# %%
# Pour télécharger la chaîne de traitement de Stanza pour la langue française
stanza.download('fr')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 26.8MB/s]
# 2021-08-06 22:15:25 INFO: Downloading default packages for language: fr (French)...
# 2021-08-06 22:15:27 INFO: File exists: /home/hugoscheithauer/stanza_resources/fr/default.zip.
# 2021-08-06 22:15:31 INFO: Finished downloading models and saved to /home/hugoscheithauer/stanza_resources.

# %% [markdown]
# ## Pré-traitement du XML PAGE

# %% [markdown]
# On récupère le XML PAGE, on le parse, et on essaye de reconstituer chaque enregistrement grâce à l'annotation sémantique réalisée dans eScriptorium.
#
# Le type:first_line correspond à chaque première ligne d'enregistrement. La première ligne du registre, indiquant la date, possède également ce label.
#
# Le modèle de segmentation qui a été utilisée attribue le label `column_odd` ou `column_pair`. La colonne centrale pourrait être récupéré en cherchant à extraire la troisième colonne pair.
#
# A chaque fin d'enregistrement, on ajoute un "@ " pour indiquer la fin de l'unité sémantique. De la sorte, on reconstitue artificiellement la structure de la page.
#
# On segmente ensuite les enregistrements en dehors de la pipeline de NLP Stanza, car je n'ai pas trouvé de sentencizer dédié pour le moment. On reproduit l'action d'un sentencizer en faisant un .split() sur "@".

# %%
tag_list = []

# On ouvre le fichier XML PAGE
with open("../../corpus_test/lectaurep/doc_28_sample/annotated_first_lines/FRAN_0025_0029_L-0.xml") as file:
    parsed_sample = BeautifulSoup(file, "lxml-xml")


# On effectue les transformations pour segmenter artificiellement les enregistrements
textline_tags = parsed_sample.find_all("TextLine")
for i in range(len(textline_tags)):
    if textline_tags[i].has_attr('custom'):
        if textline_tags[i]['custom'] == 'structure {type:first_line;}':
                # On modifie l'index précédent quand on arrive sur une balise avec @custome == 'structure {type:first_line;}'
                unicode = textline_tags[i-1].find('Unicode')
                unicode.append("@")
      
    
# On récupère les tags Unicode modifiés
unicode_tags = parsed_sample.find_all("Unicode")
text_tags_list = [tag.text for tag in unicode_tags]
# On join() les index de la liste
text = ''.join(text_tags_list)
# On essaye de reconstituer les noms aglutinés à l'aide des majuscules
text = re.sub(r"(\w)([A-Z])", r"\1 \2", text)
# On segmente les enregistrements à la main avec .split()
text_sent = text.split("@")
# On obtient une liste où chaque index correspond à un enregistrement

# On supprime le dernier index qui est vide (''), créé à cause du split sur @
text_sent = text_sent[:-1]
text_sent
# Out:
# ['An 1901, mois de Étévrier',
#  'Dupuis (par Pierre) à Paris, rue Turot 4, à Catherine Bigol, safen',
#  'a Oo (par Mve) s.n. à',
#  'Muret (de Paul Louis Georges) dt à Paris, Bd Rochechouart 68, et Marie Joséphine Lemaire, dt à Paris, même adreré (Sléparation de biens',
#  "Duboscqfet titre de 380+. de rente 3% au nom de: Debuisson, Juatine Adèle Se de Pnles) et autres, à Paris, rue del'Orcade 21",
#  'Rousfpa Pdmord Harcisse Bt a Paris, rue Canaletti 15, et autrespr touchor V',
#  'Chabr (par Marie Louise Jatoune, Ve de Marie Eusébe Maseine Bt à Billancourt ronte de Sersailles. 18, à Ougène Vahrin et Marceline Fhalino, dt à Billancourt, rue Mationale 31, de 21303.88',
#  'Gauther (par Marie Cexandinte) à Paris, rue St Ferdinandt, à sespère et mère',
#  'Oussonppar Geordes Ernert Léou dt à Paris, rue Lamarch 144, à sonpère',
#  "Lecrosnier (etlivret de Caistte d'Epargne de Paris, de157.19, aunonde Pierre Pugute) décédé en sondomicilé à P Paris, rue Descartes 21, le 16 8bre 1900",
#  'Lettéronctlespiénond de Louis Cmile) décédé ensondoui à Villneuse Heorges, le 15 7bre 187',
#  'Oupont (pr Léonie Clhrtine Détavie rue St Lazare 82, à Honoré Bouscaratets Jeune, a ntelaux (Anepon et à Cchille Pareau, rue Guyot 17 debontique aud nlier',
#  'de lecanda y Mondicta(t Joaguina Polores Conceptionde Orbeta y Alguirre V° Mannel) décédée à Bilbas. 23 calle de Ptodebavriéta le 25 Mai1900',
#  'Théonle (par Alfred Slain Geordes) dt à Paris, rue Brag. 4, à1o nee',
#  'Deeuit (par Jaéol Guillaume) dtà Paris, rue Falévy 6, deonbeusdtales appt à Mme de Boissieu',
#  'deranès (de Marie Gertade Cbout, épouse de Clodoii e Mert) dt àParis, rue du Frinteups. 32',
#  'de  Soudietat',
#  'Ste Blocq pères et Cié (parladt) répabonl à Gabiel Hanit Coyatrue du Mintemps 7, de 782%',
#  "Henriy (par Etugustine Victoire Lecharpentier, épouse de Jean Baptiste) à Parisrued'tthènes, 24, au mariade de 1lel",
#  'Moreau Simond (par Gustave Aalhur Félie) et Marie Françoise Pellerin,epre à Paris, rue des Batiquolles 76, pr vendre mmneuble',
#  'Marant (par Marie Caroline Dhval, vligalle, 16, Ve de Clexandretichor Aunand)à Joseph Eugine Royt et Marie Adelphine Julien, à Aonilres, rue de Chatandu 22, 5re 1028+ pr devente',
#  "Crat (St livret dela Caissé des retraites pourlaveillesse, 150+, aunom de Jean Joseph) décédé eu soudoi. à Paris, rue del'Amnonciation 28, le 23 8bre 1900",
#  'Toudon (de Pauline Antoinette Meyer, Veeu tresnaes de Clexandre Chatel eteu desaces de Ftrançois décédée ensondom à Paris, rue de Courcelles 192, le 21 février 1901',
#  'De Goyeneche (par Carmentdt à Paris, avenue Friedland 15, aau Mariano Nedfuaqui, Md de Villafuerté, même adressespr acq. dela Ste des Cotegux de Longchamps',
#  'Ste des socomotives sans foyer (Ct la)par Léon Strancq, à Pars18, avennue Victor Jugo',
#  "Lebedel (de Mérie Jean Baptiste) à Paris, avenue Victoria 15, et Luie Augustin Ceury, à Paris, rued'Athénes 24 Communauté réduite aux acquêts",
#  'Deloyenèche (par Juanc Mariais de Goyenèche y Gamis comté de Guaguedt à Paris, avenue Fricdlarre 15, etautres',
#  "de Goyenèche (à Carmen) dt à Paris, avenue Friedland 15, à la Sté Ste des Coteauxde Bois de Boulogne et de Longchamps, siégeà Paris, rue del'Osly 9, de 3 paralles de terrainmet 1808",
#  'Guille ( tevens de Marchautfet titre de 396 - de rente 37 auc nom de) Geurg, dt àPrmbaut Croconhill (lymonth comsté de Revon (Augletere) décédé le 9 mai 190 Bebdppiote',
#  "Anaier (par Frgngoie Ronchard, épouse de Alphonse), rue Saferrière 17, pr relireroutestommes dela Caisted'Epargnepottale",
#  'Outrey (par Marguerite Olvire Henneis, épouse de Jean Victor dt àParis, rue Lrefendre 176, pr recueillir 31',
#  'Mainot (par Engrace Millacet, épouse de Piere) dt ̀ Paris rue de Grenelle Pide Mi Mlarid clesc',
#  'Dournié (a près décè de Marie Muller, Ve de Marcelin) décéie en sondonielles Paris, rue Beuret 20, le11 février 190',
#  'Teilfparle Citnie à Fraņois) dt à Bois Cdonbes, nille Sehutz, 13, de 38 00f']

# %% [markdown]
# ## Traitements NLP

# %%
# On définit la chaîne de traitement qui nous intéresse, ici le tokenizer et le ner
nlp = stanza.Pipeline(lang='fr', processors='tokenize, ner')
# Out:
# 2021-08-06 22:15:31 WARNING: Language fr package default expects mwt, which has been added
# 2021-08-06 22:15:31 INFO: Loading these models for language: fr (French):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | ner       | wikiner |
# =======================
#
# 2021-08-06 22:15:31 INFO: Use device: cpu
# 2021-08-06 22:15:31 INFO: Loading: tokenize
# 2021-08-06 22:15:31 INFO: Loading: mwt
# 2021-08-06 22:15:31 INFO: Loading: ner
# 2021-08-06 22:15:32 INFO: Done loading processors!

# %% [markdown]
# On utilise une comprehensive list pour appliquer la pipeline Stanza sur chaque index de notre liste text_sent

# %%
# %%time
doc = [nlp(i) for i in text_sent]
# Out:
# CPU times: user 16.8 s, sys: 65.6 ms, total: 16.8 s
# Wall time: 11.9 s

# %%
# %%time
# Pour comparer le temps que cela met seulement sur une chaîne de caractères et non une liste
doc2 = nlp(text)
# Out:
# CPU times: user 22.9 s, sys: 320 ms, total: 23.2 s
# Wall time: 8.39 s

# %% [markdown]
# ## NER

# %% [markdown]
# On affiche, pour chaque enregistrement, les entités nommées reconnues par la pipeline Stanza.

# %%
for sent in doc:
    print(*[f'entity: {ent.text}\ttype: {ent.type}' for ent in sent.ents], sep='\n')
    print("\n")
# Out:
# entity: Étévrier	type: LOC
#
#
# entity: Dupuis	type: ORG
# entity: Pierre	type: MISC
# entity: Paris	type: LOC
# entity: rue Turot	type: LOC
# entity: Catherine Bigol	type: PER
#
#
# entity: Oo	type: LOC
# entity: Mve	type: ORG
#
#
# entity: Muret	type: PER
# entity: Paul Louis Georges) dt à Paris	type: PER
# entity: Bd Rochechouart	type: PER
# entity: Marie Joséphine Lemaire	type: PER
# entity: Paris	type: LOC
#
#
# entity: Duboscqfet	type: LOC
# entity: Debuisson	type: LOC
# entity: Juatine Adèle Se de Pnles	type: PER
# entity: Paris	type: LOC
# entity: rue del'Orcade	type: LOC
#
#
# entity: Rousfpa Pdmord Harcisse Bt	type: LOC
# entity: Paris	type: LOC
# entity: rue Canaletti	type: LOC
# entity: V	type: ORG
#
#
# entity: Chabr	type: PER
# entity: Marie Louise Jatoune	type: PER
# entity: Ve de Marie Eusébe Maseine Bt à Billancourt	type: PER
# entity: Sersailles	type: LOC
# entity: Ougène Vahrin	type: PER
# entity: Marceline Fhalino	type: PER
# entity: Billancourt	type: LOC
# entity: rue Mationale	type: LOC
#
#
# entity: Marie Cexandinte	type: PER
# entity: Paris	type: LOC
# entity: St Ferdinandt	type: PER
#
#
# entity: Oussonppar Geordes Ernert Léou dt	type: PER
# entity: Paris	type: LOC
# entity: rue Lamarch	type: LOC
#
#
# entity: Lecrosnier	type: PER
# entity: Caistte d'Epargne	type: PER
# entity: Paris	type: LOC
# entity: Pierre Pugute	type: PER
# entity: P Paris	type: LOC
# entity: Descartes	type: PER
#
#
# entity: Louis Cmile	type: PER
# entity: Villneuse Heorges	type: PER
#
#
# entity: Oupont	type: PER
# entity: Léonie Clhrtine Détavie	type: PER
# entity: St Lazare	type: PER
# entity: Honoré Bouscaratets Jeune	type: PER
# entity: Anepon	type: PER
# entity: Cchille Pareau	type: PER
# entity: Guyot	type: PER
#
#
# entity: de lecanda y Mondicta	type: PER
# entity: t Joaguina Polores Conceptionde Orbeta y Alguirre V° Mannel	type: LOC
# entity: Bilbas	type: PER
# entity: Ptodebavriéta	type: LOC
# entity: 25 Mai1900	type: LOC
#
#
# entity: Alfred Slain Geordes	type: PER
# entity: Paris	type: LOC
# entity: rue Brag	type: LOC
#
#
# entity: Deeuit	type: LOC
# entity: Jaéol Guillaume	type: PER
# entity: Paris	type: LOC
# entity: Falévy	type: PER
# entity: Mme de Boissieu	type: PER
#
#
# entity: Marie Gertade Cbout	type: PER
# entity: Clodoii e Mert	type: PER
# entity: rue du Frinteups	type: LOC
#
#
# entity: Soudietat	type: LOC
#
#
# entity: Ste Blocq pères et Cié	type: PER
# entity: Gabiel Hanit Coyatrue	type: PER
# entity: Mintemps	type: LOC
#
#
# entity: Etugustine Victoire Lecharpentier	type: PER
# entity: Jean Baptiste	type: PER
# entity: Parisrued'tthènes	type: PER
#
#
# entity: Moreau Simond	type: PER
# entity: Gustave Aalhur Félie	type: PER
# entity: Marie Françoise Pellerin	type: PER
# entity: Paris	type: LOC
# entity: rue des Batiquolles	type: LOC
#
#
# entity: Marant	type: PER
# entity: Marie Caroline Dhval	type: PER
# entity: Ve de Clexandretichor Aunand	type: PER
# entity: Joseph Eugine Royt	type: PER
# entity: Marie Adelphine Julien	type: PER
# entity: Aonilres	type: PER
# entity: Chatandu	type: LOC
#
#
# entity: Crat	type: MISC
# entity: St livret dela Caissé	type: MISC
# entity: Jean Joseph	type: PER
# entity: Paris	type: LOC
# entity: rue del'Amnonciation 28	type: LOC
#
#
# entity: Pauline Antoinette Meyer	type: PER
# entity: Veeu tresnaes	type: MISC
# entity: Clexandre Chatel	type: PER
# entity: Ftrançois	type: PER
# entity: Paris	type: LOC
# entity: rue de Courcelles	type: LOC
#
#
# entity: De Goyeneche	type: PER
# entity: Carmentdt	type: PER
# entity: Paris	type: LOC
# entity: avenue Friedland	type: LOC
# entity: Mariano Nedfuaqui	type: PER
# entity: Md de Villafuerté	type: LOC
# entity: Ste des Cotegux de Longchamps	type: PER
#
#
# entity: Ste des socomotives sans foyer	type: MISC
# entity: Léon Strancq	type: PER
# entity: Pars18	type: MISC
# entity: Victor Jugo	type: PER
#
#
# entity: Lebedel	type: PER
# entity: Mérie Jean Baptiste	type: PER
# entity: Paris	type: LOC
# entity: Victoria	type: PER
# entity: Luie Augustin Ceury	type: PER
# entity: Paris	type: LOC
# entity: Communauté	type: LOC
#
#
# entity: Deloyenèche	type: PER
# entity: Juanc Mariais de Goyenèche y Gamis	type: PER
# entity: Guaguedt	type: LOC
# entity: Paris	type: LOC
# entity: avenue Fricdlarre	type: LOC
#
#
# entity: Goyenèche	type: LOC
# entity: Carmen	type: LOC
# entity: Paris	type: LOC
# entity: avenue Friedland	type: LOC
# entity: Sté Ste des Coteauxde Bois de Boulogne	type: LOC
# entity: Longchamps	type: LOC
# entity: Paris	type: LOC
#
#
# entity: Guille	type: PER
# entity: Marchautfet	type: PER
# entity: Geurg	type: PER
# entity: dt àPrmbaut Croconhill	type: PER
# entity: Revon	type: PER
# entity: Augletere	type: LOC
# entity: Bebdppiote	type: PER
#
#
# entity: Frgngoie Ronchard	type: PER
# entity: Alphonse	type: PER
# entity: rue Saferrière	type: LOC
#
#
# entity: Outrey	type: PER
# entity: Marguerite Olvire Henneis	type: PER
# entity: Jean Victor dt àParis	type: PER
# entity: Lrefendre	type: PER
#
#
# entity: Engrace Millacet	type: PER
# entity: Piere	type: PER
# entity: Paris	type: LOC
# entity: Grenelle Pide Mi Mlarid clesc	type: LOC
#
#
# entity: Dournié	type: PER
# entity: Marie Muller	type: PER
# entity: Ve de Marcelin	type: PER
# entity: Paris	type: LOC
# entity: rue Beuret	type: LOC
#
#
# entity: Teilfparle Citnie	type: LOC
# entity: Fraņois	type: LOC
# entity: Bois Cdonbes	type: LOC
# entity: Sehutz	type: LOC

# %% [markdown]
# On affiche, pour chaque enregistrement, les token reconnus par la pipeline Stanza.

# %%
for idx in doc:
    print(*[f'token: {token.text}\tner: {token.ner}' for sent in idx.sentences for token in sent.tokens], sep='\n')
# Out:
# token: An	ner: O
# token: 1901	ner: O
# token: ,	ner: O
# token: mois	ner: O
# token: de	ner: O
# token: Étévrier	ner: S-LOC
# token: Dupuis	ner: S-ORG
# token: (	ner: O
# token: par	ner: O
# token: Pierre	ner: S-MISC
# token: )	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Turot	ner: E-LOC
# token: 4	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: Catherine	ner: B-PER
# token: Bigol	ner: E-PER
# token: ,	ner: O
# token: safen	ner: O
# token: a	ner: O
# token: Oo	ner: S-LOC
# token: (	ner: O
# token: par	ner: O
# token: Mve	ner: S-ORG
# token: )	ner: O
# token: s.n.	ner: O
# token: à	ner: O
# token: Muret	ner: S-PER
# token: (	ner: O
# token: de	ner: O
# token: Paul	ner: B-PER
# token: Louis	ner: I-PER
# token: Georges	ner: I-PER
# token: )	ner: I-PER
# token: dt	ner: I-PER
# token: à	ner: I-PER
# token: Paris	ner: E-PER
# token: ,	ner: O
# token: Bd	ner: B-PER
# token: Rochechouart	ner: E-PER
# token: 68	ner: O
# token: ,	ner: O
# token: et	ner: O
# token: Marie	ner: B-PER
# token: Joséphine	ner: I-PER
# token: Lemaire	ner: E-PER
# token: ,	ner: O
# token: dt	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: même	ner: O
# token: adreré	ner: O
# token: (	ner: O
# token: Sléparation	ner: O
# token: de	ner: O
# token: biens	ner: O
# token: Duboscqfet	ner: S-LOC
# token: titre	ner: O
# token: de	ner: O
# token: 380	ner: O
# token: +.	ner: O
# token: de	ner: O
# token: rente	ner: O
# token: 3	ner: O
# token: %	ner: O
# token: au	ner: O
# token: nom	ner: O
# token: de:	ner: O
# token: Debuisson	ner: S-LOC
# token: ,	ner: O
# token: Juatine	ner: B-PER
# token: Adèle	ner: I-PER
# token: Se	ner: I-PER
# token: de	ner: I-PER
# token: Pnles	ner: E-PER
# token: )	ner: O
# token: et	ner: O
# token: autres	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: del'	ner: I-LOC
# token: Orcade	ner: E-LOC
# token: 21	ner: O
# token: Rousfpa	ner: B-LOC
# token: Pdmord	ner: I-LOC
# token: Harcisse	ner: I-LOC
# token: Bt	ner: E-LOC
# token: a	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Canaletti	ner: E-LOC
# token: 15	ner: O
# token: ,	ner: O
# token: et	ner: O
# token: autrespr	ner: O
# token: touchor	ner: O
# token: V	ner: B-ORG
# token: Chabr	ner: S-PER
# token: (	ner: O
# token: par	ner: O
# token: Marie	ner: B-PER
# token: Louise	ner: I-PER
# token: Jatoune	ner: E-PER
# token: ,	ner: O
# token: Ve	ner: B-PER
# token: de	ner: I-PER
# token: Marie	ner: I-PER
# token: Eusébe	ner: I-PER
# token: Maseine	ner: I-PER
# token: Bt	ner: I-PER
# token: à	ner: I-PER
# token: Billancourt	ner: E-PER
# token: ronte	ner: O
# token: de	ner: O
# token: Sersailles	ner: S-LOC
# token: .	ner: O
# token: 18	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: Ougène	ner: B-PER
# token: Vahrin	ner: E-PER
# token: et	ner: O
# token: Marceline	ner: B-PER
# token: Fhalino	ner: E-PER
# token: ,	ner: O
# token: dt	ner: O
# token: à	ner: O
# token: Billancourt	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Mationale	ner: E-LOC
# token: 31	ner: O
# token: ,	ner: O
# token: de	ner: O
# token: 21303.88	ner: O
# token: Gauther	ner: O
# token: (	ner: O
# token: par	ner: O
# token: Marie	ner: B-PER
# token: Cexandinte	ner: E-PER
# token: )	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: O
# token: St	ner: B-PER
# token: Ferdinandt	ner: E-PER
# token: ,	ner: O
# token: à	ner: O
# token: sespère	ner: O
# token: et	ner: O
# token: mère	ner: O
# token: Oussonppar	ner: B-PER
# token: Geordes	ner: I-PER
# token: Ernert	ner: I-PER
# token: Léou	ner: I-PER
# token: dt	ner: E-PER
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Lamarch	ner: E-LOC
# token: 144	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: sonpère	ner: O
# token: Lecrosnier	ner: S-PER
# token: (	ner: O
# token: etlivret	ner: O
# token: de	ner: O
# token: Caistte	ner: B-PER
# token: d'	ner: I-PER
# token: Epargne	ner: E-PER
# token: de	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: de157	ner: O
# token: .19	ner: O
# token: ,	ner: O
# token: aunonde	ner: O
# token: Pierre	ner: B-PER
# token: Pugute	ner: E-PER
# token: )	ner: O
# token: décédé	ner: O
# token: en	ner: O
# token: sondomicilé	ner: O
# token: à	ner: O
# token: P	ner: B-LOC
# token: Paris	ner: E-LOC
# token: ,	ner: O
# token: rue	ner: O
# token: Descartes	ner: S-PER
# token: 21	ner: O
# token: ,	ner: O
# token: le	ner: O
# token: 16	ner: O
# token: 8bre	ner: O
# token: 1900	ner: O
# token: Lettéronctlespiénond	ner: O
# token: de	ner: O
# token: Louis	ner: B-PER
# token: Cmile	ner: E-PER
# token: )	ner: O
# token: décédé	ner: O
# token: ensondoui	ner: O
# token: à	ner: O
# token: Villneuse	ner: B-PER
# token: Heorges	ner: E-PER
# token: ,	ner: O
# token: le	ner: O
# token: 15	ner: O
# token: 7bre	ner: O
# token: 187	ner: O
# token: Oupont	ner: S-PER
# token: (	ner: O
# token: pr	ner: O
# token: Léonie	ner: B-PER
# token: Clhrtine	ner: I-PER
# token: Détavie	ner: E-PER
# token: rue	ner: O
# token: St	ner: B-PER
# token: Lazare	ner: E-PER
# token: 82	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: Honoré	ner: B-PER
# token: Bouscaratets	ner: I-PER
# token: Jeune	ner: E-PER
# token: ,	ner: O
# token: a	ner: O
# token: ntelaux	ner: O
# token: (	ner: O
# token: Anepon	ner: S-PER
# token: et	ner: O
# token: à	ner: O
# token: Cchille	ner: B-PER
# token: Pareau	ner: E-PER
# token: ,	ner: O
# token: rue	ner: O
# token: Guyot	ner: S-PER
# token: 17	ner: O
# token: debontique	ner: O
# token: aud	ner: O
# token: nlier	ner: O
# token: de	ner: I-PER
# token: lecanda	ner: I-PER
# token: y	ner: I-PER
# token: Mondicta	ner: E-PER
# token: (	ner: O
# token: t	ner: B-LOC
# token: Joaguina	ner: I-LOC
# token: Polores	ner: I-LOC
# token: Conceptionde	ner: I-LOC
# token: Orbeta	ner: I-LOC
# token: y	ner: I-LOC
# token: Alguirre	ner: I-LOC
# token: V°	ner: I-LOC
# token: Mannel	ner: E-LOC
# token: )	ner: O
# token: décédée	ner: O
# token: à	ner: O
# token: Bilbas	ner: S-PER
# token: .	ner: O
# token: 23	ner: O
# token: calle	ner: O
# token: de	ner: O
# token: Ptodebavriéta	ner: S-LOC
# token: le	ner: O
# token: 25	ner: B-LOC
# token: Mai1900	ner: E-LOC
# token: Théonle	ner: O
# token: (	ner: O
# token: par	ner: O
# token: Alfred	ner: B-PER
# token: Slain	ner: I-PER
# token: Geordes	ner: E-PER
# token: )	ner: O
# token: dt	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Brag	ner: E-LOC
# token: .	ner: O
# token: 4	ner: O
# token: ,	ner: O
# token: à1o	ner: O
# token: nee	ner: O
# token: Deeuit	ner: S-LOC
# token: (	ner: O
# token: par	ner: O
# token: Jaéol	ner: B-PER
# token: Guillaume	ner: E-PER
# token: )	ner: O
# token: dtà	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: O
# token: Falévy	ner: S-PER
# token: 6	ner: O
# token: ,	ner: O
# token: deonbeusdtales	ner: O
# token: appt	ner: O
# token: à	ner: O
# token: Mme	ner: B-PER
# token: de	ner: I-PER
# token: Boissieu	ner: E-PER
# token: deranès	ner: O
# token: (	ner: O
# token: de	ner: O
# token: Marie	ner: B-PER
# token: Gertade	ner: I-PER
# token: Cbout	ner: E-PER
# token: ,	ner: O
# token: épouse	ner: O
# token: de	ner: O
# token: Clodoii	ner: B-PER
# token: e	ner: I-PER
# token: Mert	ner: E-PER
# token: )	ner: O
# token: dt	ner: O
# token: àParis	ner: O
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: du	ner: I-LOC
# token: Frinteups	ner: E-LOC
# token: .	ner: O
# token: 32	ner: O
# token: de	ner: O
# token: Soudietat	ner: S-LOC
# token: Ste	ner: B-PER
# token: Blocq	ner: I-PER
# token: pères	ner: I-PER
# token: et	ner: I-PER
# token: Cié	ner: E-PER
# token: (	ner: O
# token: parladt	ner: O
# token: )	ner: O
# token: répabonl	ner: O
# token: à	ner: O
# token: Gabiel	ner: B-PER
# token: Hanit	ner: I-PER
# token: Coyatrue	ner: E-PER
# token: du	ner: O
# token: Mintemps	ner: S-LOC
# token: 7	ner: O
# token: ,	ner: O
# token: de	ner: O
# token: 782	ner: O
# token: %	ner: O
# token: Henriy	ner: O
# token: (	ner: O
# token: par	ner: O
# token: Etugustine	ner: B-PER
# token: Victoire	ner: I-PER
# token: Lecharpentier	ner: E-PER
# token: ,	ner: O
# token: épouse	ner: O
# token: de	ner: O
# token: Jean	ner: B-PER
# token: Baptiste	ner: E-PER
# token: )	ner: O
# token: à	ner: O
# token: Parisrued'tthènes	ner: S-PER
# token: ,	ner: O
# token: 24	ner: O
# token: ,	ner: O
# token: au	ner: O
# token: mariade	ner: O
# token: de	ner: O
# token: 1lel	ner: O
# token: Moreau	ner: B-PER
# token: Simond	ner: E-PER
# token: (	ner: O
# token: par	ner: O
# token: Gustave	ner: B-PER
# token: Aalhur	ner: I-PER
# token: Félie	ner: E-PER
# token: )	ner: O
# token: et	ner: O
# token: Marie	ner: B-PER
# token: Françoise	ner: I-PER
# token: Pellerin	ner: E-PER
# token: ,epre	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: des	ner: I-LOC
# token: Batiquolles	ner: E-LOC
# token: 76	ner: O
# token: ,	ner: O
# token: pr	ner: O
# token: vendre	ner: O
# token: mmneuble	ner: O
# token: Marant	ner: S-PER
# token: (	ner: O
# token: par	ner: O
# token: Marie	ner: B-PER
# token: Caroline	ner: I-PER
# token: Dhval	ner: E-PER
# token: ,	ner: O
# token: vligalle	ner: O
# token: ,	ner: O
# token: 16	ner: O
# token: ,	ner: O
# token: Ve	ner: B-PER
# token: de	ner: I-PER
# token: Clexandretichor	ner: I-PER
# token: Aunand	ner: E-PER
# token: )	ner: O
# token: à	ner: O
# token: Joseph	ner: B-PER
# token: Eugine	ner: I-PER
# token: Royt	ner: E-PER
# token: et	ner: O
# token: Marie	ner: B-PER
# token: Adelphine	ner: I-PER
# token: Julien	ner: E-PER
# token: ,	ner: O
# token: à	ner: O
# token: Aonilres	ner: S-PER
# token: ,	ner: O
# token: rue	ner: O
# token: de	ner: O
# token: Chatandu	ner: S-LOC
# token: 22	ner: O
# token: ,	ner: O
# token: 5re	ner: O
# token: 1028	ner: O
# token: +	ner: O
# token: pr	ner: O
# token: devente	ner: O
# token: Crat	ner: S-MISC
# token: (	ner: O
# token: St	ner: B-MISC
# token: livret	ner: I-MISC
# token: dela	ner: I-MISC
# token: Caissé	ner: E-MISC
# token: des	ner: O
# token: retraites	ner: O
# token: pourlaveillesse	ner: O
# token: ,	ner: O
# token: 150	ner: O
# token: +	ner: O
# token: ,	ner: O
# token: aunom	ner: O
# token: de	ner: O
# token: Jean	ner: B-PER
# token: Joseph	ner: E-PER
# token: )	ner: O
# token: décédé	ner: O
# token: eu	ner: O
# token: soudoi	ner: O
# token: .	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: del'	ner: I-LOC
# token: Amnonciation	ner: I-LOC
# token: 28	ner: E-LOC
# token: ,	ner: O
# token: le	ner: O
# token: 23	ner: O
# token: 8bre	ner: O
# token: 1900	ner: O
# token: Toudon	ner: O
# token: (	ner: O
# token: de	ner: O
# token: Pauline	ner: B-PER
# token: Antoinette	ner: I-PER
# token: Meyer	ner: E-PER
# token: ,	ner: O
# token: Veeu	ner: B-MISC
# token: tresnaes	ner: E-MISC
# token: de	ner: O
# token: Clexandre	ner: B-PER
# token: Chatel	ner: E-PER
# token: eteu	ner: O
# token: desaces	ner: O
# token: de	ner: O
# token: Ftrançois	ner: S-PER
# token: décédée	ner: O
# token: ensondom	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: de	ner: I-LOC
# token: Courcelles	ner: E-LOC
# token: 192	ner: O
# token: ,	ner: O
# token: le	ner: O
# token: 21	ner: O
# token: février	ner: O
# token: 1901	ner: O
# token: De	ner: B-PER
# token: Goyeneche	ner: E-PER
# token: (	ner: O
# token: par	ner: O
# token: Carmentdt	ner: S-PER
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: avenue	ner: B-LOC
# token: Friedland	ner: E-LOC
# token: 15	ner: O
# token: ,	ner: O
# token: aau	ner: O
# token: Mariano	ner: B-PER
# token: Nedfuaqui	ner: E-PER
# token: ,	ner: O
# token: Md	ner: B-LOC
# token: de	ner: I-LOC
# token: Villafuerté	ner: E-LOC
# token: ,	ner: O
# token: même	ner: O
# token: adressespr	ner: O
# token: acq.	ner: O
# token: dela	ner: O
# token: Ste	ner: B-PER
# token: des	ner: I-PER
# token: Cotegux	ner: I-PER
# token: de	ner: I-PER
# token: Longchamps	ner: E-PER
# token: Ste	ner: B-MISC
# token: des	ner: I-MISC
# token: socomotives	ner: I-MISC
# token: sans	ner: I-MISC
# token: foyer	ner: E-MISC
# token: (	ner: O
# token: Ct	ner: O
# token: la	ner: O
# token: )	ner: O
# token: par	ner: O
# token: Léon	ner: B-PER
# token: Strancq	ner: E-PER
# token: ,	ner: O
# token: à	ner: O
# token: Pars18	ner: S-MISC
# token: ,	ner: O
# token: avennue	ner: O
# token: Victor	ner: B-PER
# token: Jugo	ner: E-PER
# token: Lebedel	ner: S-PER
# token: (	ner: O
# token: de	ner: O
# token: Mérie	ner: B-PER
# token: Jean	ner: I-PER
# token: Baptiste	ner: E-PER
# token: )	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: avenue	ner: O
# token: Victoria	ner: S-PER
# token: 15	ner: O
# token: ,	ner: O
# token: et	ner: O
# token: Luie	ner: B-PER
# token: Augustin	ner: I-PER
# token: Ceury	ner: E-PER
# token: ,	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rued'Athénes	ner: O
# token: 24	ner: O
# token: Communauté	ner: S-LOC
# token: réduite	ner: O
# token: aux	ner: O
# token: acquêts	ner: O
# token: Deloyenèche	ner: S-PER
# token: (	ner: O
# token: par	ner: O
# token: Juanc	ner: B-PER
# token: Mariais	ner: I-PER
# token: de	ner: I-PER
# token: Goyenèche	ner: I-PER
# token: y	ner: I-PER
# token: Gamis	ner: E-PER
# token: comté	ner: O
# token: de	ner: O
# token: Guaguedt	ner: S-LOC
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: avenue	ner: B-LOC
# token: Fricdlarre	ner: E-LOC
# token: 15	ner: O
# token: ,	ner: O
# token: etautres	ner: O
# token: de	ner: O
# token: Goyenèche	ner: S-LOC
# token: (	ner: O
# token: à	ner: O
# token: Carmen	ner: S-LOC
# token: )	ner: O
# token: dt	ner: O
# token: à	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: avenue	ner: B-LOC
# token: Friedland	ner: E-LOC
# token: 15	ner: O
# token: ,	ner: O
# token: à	ner: O
# token: la	ner: O
# token: Sté	ner: B-LOC
# token: Ste	ner: I-LOC
# token: des	ner: I-LOC
# token: Coteauxde	ner: I-LOC
# token: Bois	ner: I-LOC
# token: de	ner: I-LOC
# token: Boulogne	ner: E-LOC
# token: et	ner: O
# token: de	ner: O
# token: Longchamps	ner: S-LOC
# token: ,	ner: O
# token: siégeà	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: O
# token: del'Osly	ner: O
# token: 9	ner: O
# token: ,	ner: O
# token: de	ner: O
# token: 3	ner: O
# token: paralles	ner: O
# token: de	ner: O
# token: terrainmet	ner: O
# token: 1808	ner: O
# token: Guille	ner: S-PER
# token: (	ner: O
# token: tevens	ner: O
# token: de	ner: O
# token: Marchautfet	ner: S-PER
# token: titre	ner: O
# token: de	ner: O
# token: 396	ner: O
# token: -	ner: O
# token: de	ner: O
# token: rente	ner: O
# token: 37	ner: O
# token: auc	ner: O
# token: nom	ner: O
# token: de	ner: O
# token: )	ner: O
# token: Geurg	ner: S-PER
# token: ,	ner: O
# token: dt	ner: B-PER
# token: àPrmbaut	ner: I-PER
# token: Croconhill	ner: E-PER
# token: (	ner: O
# token: lymonth	ner: O
# token: comsté	ner: O
# token: de	ner: O
# token: Revon	ner: S-PER
# token: (	ner: O
# token: Augletere	ner: S-LOC
# token: )	ner: O
# token: décédé	ner: O
# token: le	ner: O
# token: 9	ner: O
# token: mai	ner: O
# token: 190	ner: O
# token: Bebdppiote	ner: S-PER
# token: Anaier	ner: O
# token: (	ner: O
# token: par	ner: O
# token: Frgngoie	ner: B-PER
# token: Ronchard	ner: E-PER
# token: ,	ner: O
# token: épouse	ner: O
# token: de	ner: O
# token: Alphonse	ner: S-PER
# token: )	ner: O
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Saferrière	ner: E-LOC
# token: 17	ner: O
# token: ,	ner: O
# token: pr	ner: O
# token: relireroutestommes	ner: O
# token: dela	ner: O
# token: Caiste	ner: O
# token: d'Epargnepottale	ner: O
# token: Outrey	ner: S-PER
# token: (	ner: O
# token: par	ner: O
# token: Marguerite	ner: B-PER
# token: Olvire	ner: I-PER
# token: Henneis	ner: E-PER
# token: ,	ner: O
# token: épouse	ner: O
# token: de	ner: O
# token: Jean	ner: B-PER
# token: Victor	ner: I-PER
# token: dt	ner: I-PER
# token: àParis	ner: E-PER
# token: ,	ner: O
# token: rue	ner: O
# token: Lrefendre	ner: S-PER
# token: 176	ner: O
# token: ,	ner: O
# token: pr	ner: O
# token: recueillir	ner: O
# token: 31	ner: O
# token: Mainot	ner: O
# token: (	ner: O
# token: par	ner: O
# token: Engrace	ner: B-PER
# token: Millacet	ner: E-PER
# token: ,	ner: O
# token: épouse	ner: O
# token: de	ner: O
# token: Piere	ner: S-PER
# token: )	ner: O
# token: dt	ner: O
# token: ̀	ner: O
# token: Paris	ner: S-LOC
# token: rue	ner: O
# token: de	ner: O
# token: Grenelle	ner: B-LOC
# token: Pide	ner: I-LOC
# token: Mi	ner: I-LOC
# token: Mlarid	ner: I-LOC
# token: clesc	ner: I-LOC
# token: Dournié	ner: S-PER
# token: (	ner: O
# token: a	ner: O
# token: près	ner: O
# token: décè	ner: O
# token: de	ner: O
# token: Marie	ner: B-PER
# token: Muller	ner: E-PER
# token: ,	ner: O
# token: Ve	ner: B-PER
# token: de	ner: I-PER
# token: Marcelin	ner: E-PER
# token: )	ner: O
# token: décéie	ner: O
# token: en	ner: O
# token: sondonielles	ner: O
# token: Paris	ner: S-LOC
# token: ,	ner: O
# token: rue	ner: B-LOC
# token: Beuret	ner: E-LOC
# token: 20	ner: O
# token: ,	ner: O
# token: le11	ner: O
# token: février	ner: O
# token: 190	ner: O
# token: Teilfparle	ner: B-LOC
# token: Citnie	ner: E-LOC
# token: à	ner: O
# token: Fraņois	ner: S-LOC
# token: )	ner: O
# token: dt	ner: O
# token: à	ner: O
# token: Bois	ner: B-LOC
# token: Cdonbes	ner: E-LOC
# token: ,	ner: O
# token: nille	ner: O
# token: Sehutz	ner: S-LOC
# token: ,	ner: O
# token: 13	ner: O
# token: ,	ner: O
# token: de	ner: O
# token: 38 00f	ner: O
